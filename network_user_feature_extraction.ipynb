# %%
import praw
import prawcore
import pandas as pd
import numpy as np 
import glob
import os
import re
import math
import sklearn

from collections import Counter
from itertools import chain, combinations, pairwise
from tqdm import tqdm
from datetime import datetime, date

from spacy import load
import warnings
warnings.filterwarnings("ignore", message=r"\[W008\]", category=UserWarning)
# Out:
# C:\ProgramData\Anaconda3\envs\IS_596\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from transformers import pipeline
sentiment_analysis = pipeline("sentiment-analysis")
sentiment_toxicity = pipeline("sentiment-analysis", model="unitary/toxic-bert")

tokenizer_kwargs = {'padding':True,'truncation':True,'max_length':512}
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)

# %%
path = 'data'
user_dir = 'user_data/user_networks'
reddit = praw.Reddit(
    client_id='4bDjCY6y8ncrc3kLrBbpBg',
    client_secret='zPHZKfk9S666S9IxR5HtvkZ83ufNxw',
    user_agent='webcrawler created for IS596'
)
nlp = load('en_core_web_md')

# %%
def normalize(text):
    norm_text = []

    for token in text:
        if not token.is_punct and not token.is_stop and not token.is_space:
            norm_text.append(token.lemma_.lower())

    norm_text = ' '.join(norm_text)
    norm_text = re.sub(r'(?:^| )\w(?:$| )', ' ', norm_text).strip()  # removes single characters
    norm_text = re.sub(r'[^a-zA-Z0-9 ]', '', norm_text)
    
    return norm_text

# %%
def get_user_status(path):
    try:
        user.is_suspended
        user_status = 'suspended'
    except AttributeError:
        user_status = 'active'
    except:
        user_status = 'deleted'
    return user_status

# %%
infile_name = f'{path}/network_list.csv'
infile = open(infile_name, 'r')
file_df = pd.read_csv(infile)
print(file_df)
# Out:
#                                                    0
# 0  ['Lord-Sprinkles', 'Final_Exit92', 'anonymous_...
# 1  ['Lord-Sprinkles', 'eaglesnation11', 'ninernet...
# 2  ['BinyaminDelta', 'frugal_masturbater', 'BackO...
# 3  ['BinyaminDelta', 'AutoModerator', 'XxSpruce_M...
# 4  ['bichonista', 'dunnkw', 'kingmoobot', 'Bloopi...
# 5  ['bichonista', '3.32299E+13', 'PeopleCanBeThis...
# 6  ['ummmbacon', 'nosecohn', 'canekicker', 'chx_'...
# 7  ['ummmbacon', 'nosecohn', 'bpetersonlaw', 'ext...

# %%
network_list = []

for i in range(len(file_df)):
    for j in range(len(file_df.iloc[[i]])):
        clean_user_names = []
        user_names = file_df.iloc[i, j]
        user_names = user_names.split(',')
        for user_name in user_names:
            user_name = user_name.strip("][' ")
            clean_user_names.append(user_name)
            
        network_list.append(clean_user_names)
        
network_list
# Out:
# [['Lord-Sprinkles',
#   'Final_Exit92',
#   'anonymous_lighting',
#   'Kitsunezaki',
#   'bleedingjim',
#   'Jos_Meid',
#   'Calm-Hovercraft9858',
#   'bpatches701',
#   'joculator',
#   'No_Key4143',
#   'BillyQz',
#   'f1sh98',
#   'kingbankai',
#   'FireNETwork',
#   'FiendishPole',
#   'Jizzlobber42',
#   'KnowledgeAndFaith',
#   'FelderMan25',
#   'HKatzOnline',
#   'Bejeweled_Bird',
#   'DLDabber',
#   'BanzaKongo',
#   'iwantnews1',
#   'freeneedle',
#   'Lola2050',
#   'JoeBroski09',
#   'KeyStep8',
#   'C4RP3_N0CT3M',
#   'Torque_Bow',
#   'Steak_N_Cocunuts',
#   'Ralath0n',
#   'IncelWomenRespecter',
#   'JustaCodfish',
#   'BathWifeBoo',
#   'TruthfulTrolling',
#   '12161986',
#   'AFishNamedFreddie',
#   'humanglove',
#   'DeliciousPussyNectar',
#   'skyrne_isk',
#   'MrColepuck',
#   'ancilla1998',
#   'TankerD18',
#   'Cinnadillo',
#   'SmoothSecond',
#   'Icylibrium',
#   'Spartanlegion117',
#   'flopisit',
#   'TheSecond48',
#   'ImAMaaanlet',
#   'Shirley-Eugest',
#   'sleeknub',
#   'officialwipe',
#   'NA_DeltaWarDog',
#   'ThirdRook',
#   'Hydrocoded',
#   'Morganbanefort'],
#  ['Lord-Sprinkles',
#   'eaglesnation11',
#   'ninernetneepneep',
#   'Imdatingstaceysmom',
#   'freeneedle',
#   'dirtyALEK',
#   'itsnunyabusiness',
#   'casey_the_evil_snail',
#   'TheRayquazaLord',
#   'AlpacaWarMachine',
#   'AegonTheBest',
#   'Obduraterthanthepast',
#   'ytilonhdbfgvds',
#   'urinemygape',
#   'toxygen',
#   'BossLoaf1472',
#   'Eadweard85',
#   'Most_kinds_of_Dirt',
#   'ThePolarBare',
#   'GayByTheBay',
#   'BrokenArrows95',
#   'Alfonze423',
#   'KeyStep8',
#   'randomguest59',
#   'KelpCakeDanny',
#   'dantian',
#   'ChainingScroll2',
#   'Gua_Bao',
#   'uponone',
#   'kempff',
#   'DangerRanger-69',
#   'cowabungaboogaloo',
#   'Dudes-Abide',
#   'longboringstory',
#   'Imissyourgirlfriend2',
#   'stolid_agnostic',
#   'Cranky-George',
#   'ValuableJellynut',
#   'mariobrowniano',
#   'potatocakesssss',
#   'DEM_DRY_BONES',
#   'hpjj',
#   'MostlyPretentious',
#   'NickMotionless',
#   'Final_Exit92',
#   'papasoilpants',
#   'LuckyRyder',
#   'anony8165',
#   'ETChunter95',
#   'DrJoshuaWyatt',
#   'ChicagoReddd',
#   'searing7',
#   'anonymous_lighting',
#   'InnateConservative',
#   'RealBlackberry',
#   'teddy_bear_territory',
#   'Kitsunezaki',
#   'Odd-Wheel',
#   'Between_three_and20',
#   'SocraticSalvation',
#   'TheDukeSam',
#   'WillamThunderAct',
#   'Jeremy_Whalen',
#   'disisdashiz',
#   'AbjectDisaster',
#   'K0N1NG',
#   'bearish_bool',
#   'oorara5',
#   'Barts_Frog_Prince',
#   'SoIJustBuyANewOne',
#   'Redd_Baby',
#   'En_Sabah_Nur',
#   'TwoBuckExacta',
#   'sleeknub',
#   'ThePelicanThatCould',
#   'Fast-Ad2235',
#   'Manbadger',
#   'KermitThe__Frog',
#   'sir_gobbles7',
#   '99available',
#   'Triforceoffarts',
#   'SVMESSEFVIFVTVRVS',
#   'BackgroundElephant94',
#   'Alphaetus_Prime',
#   'aesthetickunt69',
#   'ConscientiousPath',
#   'Ashhole37',
#   'Emotional-Key-653',
#   'DestroyTheFascies',
#   'NWbySW',
#   'Pedinhuh',
#   'I_SHOT_CHENEYS_HOMIE',
#   'TenDollarSteakAndEgg',
#   'all_natural49',
#   'Complex-Ad237',
#   'JamesSag',
#   'sneaky-the-brave',
#   'TylrLS',
#   'jthreat21',
#   'Historical-Ad6120',
#   'Dangerous_Concept341',
#   'CressInteresting',
#   'neibegafig',
#   'KiLLaHMoFo',
#   'Phoenix_Lamburg',
#   'JustAnotherPeasant01',
#   'leathebimbo',
#   'TheFlyWasRight',
#   'GAMBT22',
#   'INoScopedBambi',
#   'ocket8888',
#   'Destructicore',
#   'alexaxl',
#   'Exogenic',
#   'HoovyTooby',
#   'Rotorist',
#   'Nothingiscoolman',
#   'WarsledSonarman',
#   'InfowarriorKat',
#   'ItsJustMeMaggie',
#   'chenbuxie',
#   'maxis2bored',
#   'thefinalshill',
#   'shining_wizard_',
#   'Delifier',
#   'BABarracus',
#   'soldmytokensformoney',
#   'epic_pig',
#   'T4mvv1lc0xx',
#   'FearsomeShitter',
#   'PaulfussKrile',
#   'Joe_30330',
#   'Krombopolus_M',
#   'tamasiaina',
#   'Rxpha',
#   'RevolutionaryFig69',
#   'cbobley',
#   'CommanderPike',
#   'PerfectDark_SIXFOUR',
#   'bleedingjim',
#   'sumdude1849',
#   'Canonmeat',
#   'TomXFoolery',
#   '2klaedfoorboo',
#   'grotebozesmurf',
#   'KillsburyShowBoy',
#   'Harvey1010101010',
#   'rationalobjector',
#   'dariuskxx',
#   'anbnzb',
#   'Lepew1',
#   'CSKweh',
#   'Jimmy_cracks_Corn',
#   'NuNyOB1dNaSs',
#   'ThiccestNibbaNA',
#   'joeynsf',
#   'Jamones-chicharones',
#   'thesaucewalker',
#   'JTuck333',
#   'comfortablynumb0629',
#   'rebelliousjuicebox',
#   'GardenOfSpoons',
#   'BTK-LOL',
#   'trextec',
#   'PilotNGlide',
#   'TSTEP1971',
#   'Hot-Equivalent9189',
#   'Tramplamp69420',
#   'backflash',
#   'Ok_Farmer_5869',
#   'ReporterLeast5396',
#   'airplantenthusiast',
#   'BullyCongressDotCom',
#   'Chance_Butterfly_987',
#   'DreadPirateGriswold',
#   'DV_Police',
#   'wuggyLuv',
#   'ambermage',
#   'The_RedWolf',
#   'NoleFan723',
#   'averageuhbear',
#   'GovernmentAgent_Q',
#   'BoredRenaissance',
#   'MyTrademarkIsTaken',
#   'Darkelementzz',
#   'MaxP0wersaccount',
#   'blackgold7387',
#   'No-Feedback7437',
#   'TJATAW',
#   'Randy519',
#   'gohoos1990',
#   'Randicore',
#   'adequacyenhanced',
#   'acvdk',
#   'Smurf_Sausage_Sucker',
#   'Miles-Standoffish',
#   'Thiege227',
#   'CrimsonReign07',
#   'HerrNachtWurst',
#   'bungholebuffalo',
#   'JaceM15',
#   'matrixnsight',
#   'dunktheball',
#   'Legitimate_Teddy',
#   'iamthefluffyyeti',
#   'someguyjoe',
#   'RandomGameplayStuff',
#   'plague681',
#   'Ambitious_Scholar823',
#   'Maevios',
#   'Aggressive-Arm9724',
#   'Pyroboss101',
#   'khaste',
#   'Life-Is-Evil',
#   'kenny-klogg',
#   'TomorrowsHeroToday',
#   'AndersFreeden',
#   'PinedCortes',
#   'ppanther92',
#   'MeowMixYourMum',
#   'PulledPorkPlease',
#   'ArchmageLiam',
#   'ProximalTripper',
#   'PigViper22',
#   'Grimm6066',
#   'RealEastNasty',
#   'Anubisrapture',
#   'douggold11',
#   'jtkchen',
#   'BillLaswell404',
#   'NoTownBoy',
#   'databoy-thatsme',
#   'ei4nr4z',
#   'Lukee__01',
#   '1RookieSysAdmin',
#   'stetsonmarshal',
#   'OkBeing9818',
#   'MethodBorn6289',
#   'Low_Historian_7552',
#   '_scorchy_',
#   'IBitchSLAPYourASS',
#   'infamousmetre',
#   'Sintinall',
#   'oilybarbour',
#   'jexmex',
#   'Jos_Meid',
#   'dgembeaux43',
#   'Todef_',
#   'Aurex86',
#   'FartPartyFriday',
#   'Aitloian',
#   'kingblow1',
#   'Sufficient_Boss_6782',
#   'Simpoge39',
#   'WarLord055',
#   'D-utch',
#   'somehting',
#   'AdEffective8044',
#   'saltedpecker',
#   'buahuash',
#   '96-62',
#   'redditisaweful1',
#   'DonJuanDeMichael1970',
#   'SaraACarter',
#   'erconn',
#   'CuppaSouchong',
#   'crazypostman21',
#   'WinstonJrIII',
#   'PM_BoobsnButts_pls',
#   'liberia_simp',
#   'no_one27',
#   'Sector7B',
#   'biscuitslayer77',
#   'NsRhea',
#   'XIIXOO',
#   'getahitcrash',
#   'Roundaboutsix',
#   'Grundlepunch3000',
#   'Sirsmellz',
#   'RexErection',
#   'gotyour66',
#   'FalafelImChips',
#   'gcanders1',
#   'Brandycane1983',
#   'FiendishPole',
#   'MattyIcex4',
#   'Icantthinkofagoo',
#   'Tasty_Chick3n',
#   'RudeIBegYa',
#   'Semirahl',
#   'Started_WIth_NADA',
#   'Ms1776',
#   'Exzalia',
#   'Hydrocoded',
#   'jcoving28',
#   'TheNarratorsVoice',
#   'Intelligent_Plan_747',
#   'Leading_Tooth_8957',
#   'ronfun',
#   'Mengem2',
#   'Kolesko',
#   'rboes1991',
#   'dopestdope69',
#   'ChoiceCriticism1',
#   'spinsterchachkies',
#   'TheAccountant1928',
#   'kamera45',
#   'sorathecrow__',
#   'microcosm315',
#   'LadenifferJadaniston',
#   'TheFerretman',
#   'Starlifter4',
#   'leeroycharles',
#   'datastrm',
#   'Mka28',
#   'kevin_panda',
#   'Bykeracr',
#   'IceTruckHouse',
#   'Jobu72',
#   'NinjaGuyDan777',
#   'Karukash',
#   'BlockinBlack',
#   'TroyMcClure10',
#   'OrdoXenos',
#   'LetsMakeThisHappen12',
#   'ghostwh33l',
#   'DominicanJedi',
#   'Lurkay1',
#   'DJHJR86',
#   'FoMoCoguy1983',
#   'anjovis150',
#   'CollegeNW',
#   'Green_Juggernaut1428',
#   'killaknott27',
#   'AlphaCueRough',
#   'haughty_thoughts',
#   'LimitNo6587',
#   'susman01',
#   'DLoFoSho',
#   'SnooTigers6381',
#   'XfitRedPanda',
#   'Mr_Swampthing',
#   'blaze_blue_99',
#   'Ceegee_30',
#   'pmabraham',
#   'Godspeedhack',
#   'anonymous-034',
#   'wowokletstalkabit',
#   'ORCA_OF_WALLST',
#   'MaintenanceFar8903',
#   'BebopRocksteady82',
#   'vibhui',
#   'chimpset4life',
#   'ssebastian364',
#   'BeachCruisin22',
#   'biggybenis',
#   'Dezco14',
#   'NunyaBeese',
#   'YARNIA',
#   'Slylizardcue',
#   'TheTarasenkshow',
#   'MountainousFog',
#   'Nergaal',
#   'ccc32224',
#   'Calm-Hovercraft9858',
#   'GargantuanCake',
#   'BishopGodDamnYou',
#   'Captain-Insane-Oh',
#   'veryscary_gary',
#   'ConditionalDew',
#   'Make_it_happn_captn',
#   'tilfordkage',
#   'PseudoFuse',
#   'triggoon',
#   'jpfeif29',
#   'BubbleBassV2',
#   'wilson1474',
#   'jthizz77',
#   'Gesno',
#   'Whyamiherewtflmaoidc',
#   'Rumpdohg',
#   'BananaRamaBam',
#   'georgesDenizot',
#   'After-Cold-4689',
#   'Dutchtdk',
#   'BDSF94',
#   'lonely_hero',
#   'TheSeventhWon',
#   'ambearlino',
#   'PEneoark',
#   'eked-1213',
#   'Ajkrouse',
#   'FarCenterExtremist',
#   'tms358',
#   'NinjaNard_',
#   'smrtrthnuravgbr',
#   'ce_roger_oi',
#   'hex5912',
#   'Bolt408',
#   'Medical-Boa',
#   'openwindowrain',
#   'TooDenseForXray',
#   'Sparky8924',
#   'TRAIN_WRECK_0',
#   'HotPoptartFleshlight',
#   'BigDaddyCoolDeisel',
#   'Ok_Inspector_5919',
#   'Cheap_Amphibian309',
#   'Mitchisboss',
#   'ronpaulclone',
#   'GunterBoden',
#   'Jooceizlooce_',
#   'Greenman_on_LSD',
#   'nuclear_hangover',
#   'El-Lamberto',
#   'mdh431',
#   'future_web_dev',
#   'nivekreclems',
#   'JethroFire',
#   'Bannanaballoons',
#   'rexofit',
#   'BonahBoffey',
#   'IndiaEvans',
#   'OpsEnderX',
#   'Maxy9898',
#   'brookrain',
#   'FriscoTec',
#   'Kidcody44',
#   'msxzf8u3',
#   'HermanDinklemyer',
#   'Parrabola213',
#   'ElectronicReference5',
#   'SquirttleTurtle',
#   'lewman1990',
#   'CHEROKEEJ4CK',
#   'crypt0_sports',
#   'ComplexEmphasis',
#   'KingOfAgAndAu',
#   'FormerBTfan',
#   'Bladesman08',
#   'ther1ckst3r',
#   'BisterMee',
#   'bpatches701',
#   'SnooTomatoes1445',
#   'Equivalent_Nature_67',
#   'beardophilosophy',
#   'itachiofthesand',
#   'QuesoStain',
#   'loplopplop',
#   'Jolaasen',
#   'capintachunkie',
#   'seoyeonhwa',
#   'Skibiscuit',
#   'rattymcratface',
#   'IntenseSpirit',
#   'Spartanwildcats2018',
#   'red-african-swallow',
#   'mooseandsquirrel78',
#   'Past-Passenger9129',
#   'IgnacioCashmere',
#   '5538293',
#   'purpledoom313',
#   'Freedom_fam',
#   'TormundGingerBeard',
#   'Stoicker55',
#   'LogicalMan2',
#   'HoraceGrand',
#   'KennedyX8',
#   'hunterbidenslaptop2',
#   'Ambitious-Mirror-315',
#   'ghandiboi7',
#   'brownbrothaa',
#   'i_like_2_travel',
#   'launcelot02',
#   'IcyAdvertising3771',
#   'Political_Weebery',
#   'Bronqiaa',
#   'You_madbro',
#   'Stormveil138',
#   'Doktor_Dysphoria',
#   'meeeemeees',
#   'Duster26to29',
#   'Such-Veterinarian983',
#   'biccat',
#   'meatballther',
#   'Japan_the_Loser',
#   'cmdrcaboose2',
#   'luciferschildx',
#   'KennethGames45',
#   'commonsenseulack',
#   'Individual-Jaguar885',
#   'duracel2002',
#   'Aviator1116',
#   'GILFMunter',
#   'Unlikely-Distance-92',
#   'aproudfatherof3',
#   'kraotic8321',
#   'biomech120',
#   'lordoftheeyes2020',
#   'i_have_a_pet_turkey',
#   'druidjax',
#   'papaXeno',
#   'Komara1',
#   'Zachmode',
#   'joculator',
#   'MrUnknown1996',
#   'No-Independent-8825',
#   'Hyperioc',
#   'MandatoryDissent50',
#   'Jor_in_the_North',
#   'One-Winner-8441',
#   'GrandpaHardcore',
#   'No_Key4143',
#   'obsessed_mechanic',
#   'RollTider1971',
#   'liquidreferee',
#   'MCKlassik',
#   'Trainpower10',
#   'RedditorNamedEww',
#   'FindingMyPrivates',
#   'Sharp-Expression9135',
#   'DarthVegeta51',
#   'nothingistrue13',
#   'notchrollou',
#   'Ani_MeBear',
#   'Scrolliver_',
#   'aybabyaybaby',
#   'dheidjdedidbe',
#   'YiddishMcSquidish',
#   'Express-Secret1802',
#   'Dominic-Vyper',
#   'woopdedoodah',
#   'FreshOutdoorAir',
#   'whentheworldquakes',
#   '585unicycleguy',
#   'MeetSpirited',
#   'splinglols',
#   'eilenedover',
#   'Bloodytomvayne34',
#   'Terribleturtleharm',
#   'AbortionJar69',
#   'Blue_Cheese_Olives',
#   'Available-Moose-1408',
#   'twitchymctwitch2018',
#   'investmentfailure',
#   'TechenCDN',
#   'LordBloodSkull',
#   'Independent_Prune_35',
#   'SuspiciousMeat6696',
#   'AmericanOdin5',
#   'Ace_W',
#   'Ineverheardofhim',
#   'kiiyyuul',
#   'david-writers',
#   'Danmerica67',
#   'Jim_Morrison27',
#   'Ryaisho',
#   'nostyle907',
#   'Emergency_Reason_242',
#   'BookHobo2022',
#   'richardstarr',
#   'BeefCakeBob',
#   'SingleRelationship25',
#   'beverly3717',
#   'OA12T2',
#   'bigdelite',
#   'Malithirond',
#   'Boltman35',
#   'BayBel',
#   'pelftruearrow',
#   'CrucialVibes',
#   'killakev564',
#   'ringo_mogire_beam',
#   'Tv_land_man',
#   'troubledtimez',
#   'BenAustinRock',
#   'ailocha',
#   'weiss27md',
#   'ObadiahtheSlim',
#   'soneast',
#   'zuk86',
#   'pthorpe11',
#   'davidiseye',
#   'supersecretaccount82',
#   'CorrectTowel',
#   'BillyQz',
#   'Adventurous_Fig_406',
#   'GrizzlyLeather',
#   'Seamus_A_McMurphy',
#   'wiseguy2235',
#   'intelligentreviews',
#   'Jaistreet',
#   'Aggressive-Cry7940',
#   'Constant-Meat8430',
#   'SinisterLeer',
#   'HillbillySwank',
#   'uh72amech',
#   'Mr_Robots',
#   'upon_a_white_horse',
#   'JeffsD90',
#   'snappahed',
#   'BuicksAreCool',
#   'angelarise3',
#   'showsmewhatyouhas',
#   'scaredtotellyou',
#   'JohnnyTheSpartan',
#   'Mrprivatejackson',
#   'TheChiefOfBeef',
#   'bob69joe',
#   'Foobucket',
#   'KnightScuba',
#   'Smooth_Friend7890',
#   'TadKosciuszko',
#   'MikeOxlong1776',
#   'milebootwalker',
#   'DarthBurger1',
#   'r777m',
#   'don_kong1969',
#   'leothebeertender',
#   'ElMatasiete7',
#   'king_of_programmers',
#   'Hot-Bat-4537',
#   'snow_king_1985',
#   'HungLikeMike69',
#   'Barbados_slim12',
#   'FreeThingsAreNice',
#   'GoblinsStoleMyHouse',
#   'rockstar2022',
#   'TheGoldenChotskie',
#   'Elo-quin',
#   'sidragon',
#   'MavicFan',
#   'luffmatcheen',
#   'bmrvkia',
#   'Ultramonte',
#   'RedAtomic',
#   'AdCritical9970',
#   'jonfromdelocated',
#   'JackBuddy0',
#   'Freddy_and_Frogger',
#   'Environmental_Car542',
#   'Smellin_Fartz',
#   'gentmaxim',
#   'hisox',
#   'imverysuperliberal',
#   'Fill-E-Cheez',
#   'Sausagesandpeppers',
#   'larrythetarry',
#   'RuckRidr',
#   'gh1993',
#   'haapuchi',
#   'south_paw01',
#   'Oscarwilder123',
#   'Downtown_Ice692',
#   'Pata4ev',
#   'nowhearmeout',
#   'Sheer10',
#   'JewPhone_WhoDis',
#   'DrButtCheeksPhD',
#   'Beeleeve2',
#   'hollowenigma4',
#   'the_neon_cowboy',
#   'haliker',
#   'BhyllieH',
#   'DeKrazyK',
#   'Duane_Earl_for_Prez',
#   'lawlygagger',
#   'va1958',
#   'ibanez3789',
#   'RealisticIllusions82',
#   'Hotwheelsjack97',
#   'HalfLucky',
#   'OneExpensiveAbortion',
#   'EdibleMrpants',
#   'Rivsmama',
#   'Rogerwaters65floyd',
#   'Nicnatious',
#   'Av1dredditor',
#   'hyperious_',
#   'Blake1610',
#   'TurdGravy',
#   'Lord_Sicarius',
#   'JablesRadio',
#   'RayCumfartTheFirst',
#   'Zaderhof',
#   'Domsdad666',
#   'alisacp',
#   'michaelmyers1997',
#   'ThePenetrathor',
#   'tingly_bits',
#   'AstonGlobNerd',
#   'itsnotaflamethrower',
#   'npc_5588',
#   'second_account_pt2',
#   'RobSavageBro',
#   'Charlezard18',
#   'Appropriate_Ad_9169',
#   'chigoonies',
#   'pimpinassorlando',
#   'NoBullfrog2',
#   'Dull_Association2398',
#   'abominable_bro-man',
#   'FriendofAgency',
#   'Le4chanFTW',
#   'YacubsLadder',
#   'WunTu92',
#   'sallyray69',
#   'ShrewdGuitar472',
#   'Dessssspaaaacito',
#   'thelosttruths',
#   'PrestigiousShift3628',
#   'GUCCIBUKKAKE',
#   'Gullible-Device-7075',
#   'AlostDinosaur',
#   'davegooley',
#   'Wizel--Balan',
#   'danomoc',
#   'topstocktips',
#   'ArgusInkArt',
#   'RTManRay',
#   'Polar_Stardust',
#   'ButterAndPaint',
#   'GalaxyZombie',
#   'chillin_impractical',
#   'devictionne',
#   'UltimateKat420',
#   '-Sean_Gotti-',
#   'whiskyforpain',
#   'CapableCitron6357',
#   'AnAngryPolarBear',
#   'rguth923',
#   'Knight3391',
#   'DickTrainButts',
#   'cevapboi47',
#   'kossimak',
#   'ant451911',
#   'nunicorn25',
#   'Resource_Past',
#   'Shadeauxmarie',
#   'revenge_of_hamatachi',
#   'ChocolateBiscuit96',
#   'cblackbeard',
#   'mortepa',
#   'RULINGCHAOS',
#   'pbar',
#   'arbiter_0115',
#   'StealUr_Face',
#   'George_The_8th',
#   'YNPCA',
#   'realtychik',
#   'SkateJerrySkate',
#   'tslog724',
#   'FTF-GREEDY',
#   'grnranger1',
#   'RCRN',
#   'ReklessS0ul',
#   'ChefDolemite',
#   'Artist_X',
#   'PraiseEnby',
#   'computershateme77',
#   'kankelberri',
#   'DailyPlaneteer',
#   'dog_in_the_vent',
#   'whutupmydude',
#   'IsItTheFrankOrBeans',
#   'Wamgurl',
#   'f1sh98',
#   'joelman0',
#   'robin_ILLiams',
#   'Eyeoftheleopard',
#   'PJsDAY',
#   'DavidPT40',
#   'slapclap28',
#   'TacoBallerina',
#   'Quartz_Lead',
#   'Maverick_OS',
#   'hankbaumbachjr',
#   'rcjack86',
#   'ENFJPLinguaphile',
#   'Frequent_Orange5409',
#   'Shwiggity_schwag',
#   'FALSE_PROFiiiTs',
#   'lifted333up',
#   'BeetleJuiceBabaBooey',
#   'thevoidcaptain',
#   'bastion72',
#   'de99102',
#   'Redskinsfan597',
#   'Germmme',
#   'Bigmans9',
#   'Prize_Self_6347',
#   'nickcliff',
#   'moesif_',
#   'Cleakman',
#   'Rezenator',
#   'andyftp',
#   'solarity52',
#   'ZebraBurger',
#   'dollarmenuaddict',
#   'MagnumHippo',
#   'IncelWomenRespecter',
#   'LordStunod',
#   'WolvenHunter1',
#   'TheEarthWorks',
#   'Phillipinsocal',
#   'Come-and-take-it-joe',
#   'go55ama',
#   'kingbankai',
#   'Southall1960',
#   'SecretlyCelestia',
#   'East_Apartment1112',
#   'shnapperss',
#   'livefreeordie83',
#   'respect1776',
#   'Scrooge_mcDuck_1867',
#   'Afraid_Prize_6853',
#   'Wonderful-Tart-6662',
#   'Smoke401',
#   'brutishbloodgod',
#   'BohdiTheNorseman',
#   'ses29680',
#   'RedditsLittleSecret',
#   'velesxrxe',
#   'Cl4ymist3r',
#   'Bulrog22',
#   'middleright92',
#   'TheRealAlexLifeson',
#   'AtAllCostSpeakTruth',
#   'Nalu247',
#   'thatisprettydumb',
#   'Fermensense',
#   'DevelopmentNo4475',
#   '_That_One_Fellow_',
#   'kicker58',
#   'htisme91',
#   'HappyHound',
#   'free-minded',
#   'Redditthedog',
#   'DMcCallister',
#   'MyFianceMadeMeJoin',
#   'Orange_milin',
#   'UnlimitedMetroCard',
#   'Averygirl11',
#   'Leather-Clock1917',
#   'FireNETwork',
#   'billgigs55',
#   'Serpenta91',
#   'Running_Gamer',
#   'ktufo',
#   'AlwayzPro',
#   'WeAreEvolving',
#   'halfcow',
#   'mr_gerald_sathior',
#   'mwatwe01',
#   'danram90',
#   'rivenhex',
#   'TommySawyer',
#   'Hywaystar74',
#   'STIGANDR8',
#   'Jizzlobber42',
#   'DesertDouche',
#   'EscapeMyJourney',
#   'smeldridge',
#   'TheArchdude',
#   'SonicChiliDogFetish',
#   'McBonderson',
#   'tambarskelfir',
#   'JaceMalcolm',
#   'Cockroach-Jones',
#   'skywalkerr69',
#   'i_will_cut_u',
#   'BornIn80',
#   'Creski',
#   'BABYFACEBARBER',
#   'CriticalBullMoose',
#   'whicky1978',
#   'tnsmaster',
#   'Sauvignon_Bleach',
#   'charlievalentine93',
#   'blizzardice',
#   'Polar--Vortex',
#   'Genoa_',
#   'pogo6023',
#   'Shooter_McGavin27',
#   'CGB1967',
#   'freedomhertz',
#   'whimsicallurker',
#   'Endoxa',
#   'patrickt333',
#   'BurgerKingslayer',
#   'KnowledgeAndFaith',
#   'AutoModerator',
#   'probably_something',
#   '1776The_Patriot',
#   'Unclerenty',
#   'sabre007',
#   'bionic80',
#   '1EyedWyrm',
#   'Sanarcin',
#   '1WontDoIt',
#   'chanbr',
#   'stvnfrnr',
#   'ElectricCow15',
#   'Deaglesringin',
#   'freebirdls',
#   'Dark-Pit-37',
#   'BlackSwanDUH',
#   'zerofukstogive2016',
#   'Suzookus',
#   'RebelRebel62',
#   'gabrielsol',
#   'Skynet-supporter',
#   'yojimbo556',
#   'mrarming',
#   'Ods2',
#   'krayhayft',
#   'Undisputed138',
#   'Masterblaster13f',
#   'skyrne_isk',
#   'ValenTheElf',
#   'hb9nbb',
#   'FitzyFarseer',
#   'KnightAngler',
#   'Who_Your_Pal',
#   'arrjay123',
#   'IRefuseToBeAshamed',
#   'LoganSettler',
#   'Jkarno',
#   'AnonymousPlzz',
#   '1991TalonTSI',
#   'TrJ4141',
#   'Clevzzzz',
#   'FelderMan25',
#   'OmegaReddit__',
#   'Fa1alErr0r',
#   'pimpieinternational',
#   'Liberdelic',
#   'Das_KV',
#   'Chewyk132',
#   'polerize',
#   'Lucretius',
#   'Moosemaster21',
#   '__Roof_Pizza_',
#   'HKatzOnline',
#   'Stonks0r',
#   'ThatGuy3488',
#   'Pink_Britches',
#   'Weekly-Butterscotch6',
#   'DogMechanic',
#   'Potential-Dog4943',
#   'bigbrotherswatchin',
#   'tharkyllinus',
#   'KAZVorpal',
#   'FlatTire2005',
#   'Bigredmachine878',
#   'Ok_Economics9476',
#   'Herp-a-titus',
#   'PyrusD',
#   'Super_Saiyan_Sudoku',
#   'greatatdrinking',
#   'Oblivion_18',
#   'MikeR1114',
#   'wiredcrusader',
#   'Racheakt',
#   'profressorpoopypants',
#   'wannabe_traveler',
#   'ProudPlatinean',
#   'NotEvenALittleBiased',
#   'monsterpoodle',
#   'HoldTime1831',
#   'Leeerrrooyyyjennkins',
#   'memphisgrit',
#   'WestforkTraveler',
#   'Flyb0mb',
#   'NYforTrump',
#   'Ouiju',
#   'kajarago',
#   'ProphetOfChastity',
#   '2468-centralus',
#   'Doyouevenbeard',
#   'Gpda0074',
#   '_TheConsumer_',
#   'wollier12',
#   'throwaway3569387340',
#   'Fun-Possibility-1060',
#   'VinnieMacYOLO',
#   'Vertisce',
#   'Period_Licking_Good',
#   'JurassicParkFood',
#   '_IsThisTheKrustyKrab',
#   'Realistic-Tear-9300',
#   'Important_Mud_2329',
#   'Severe-Exam-9470',
#   'ElectricTurtlez',
#   'Powerlineconcert',
#   'Hunter_punch',
#   'sswick64',
#   '#NAME?',
#   'Apetardo',
#   'tysoncrosby21',
#   ...],
#  ['BinyaminDelta',
#   'frugal_masturbater',
#   'BackOnThrottle',
#   'arnott',
#   'Aggressive_Egg_9661',
#   'Ok-Entrepreneur-4466',
#   'TXreddest',
#   'cloudskip',
#   'Legitimate_Finding44',
#   'pacmanpill',
#   'OmegaOverlords',
#   'bman567',
#   'olymp1a',
#   'bleszt',
#   'Wild_Frosting_5353',
#   'lraynor6',
#   'AdministrativeMost45',
#   'not-the-fake-DG',
#   'blue-moves',
#   'QuarantineSucksALot',
#   'SteadmanDillard',
#   'forthemotherrussia',
#   'AutoModerator',
#   'EarlOfMarr',
#   'Far_Iron',
#   'Charming_Ad_1216',
#   'KayneC',
#   'ultimatefighting',
#   'a_distantmemory',
#   'Confettiman',
#   'empathetical',
#   'Icy_Elevator_1406',
#   'electron65',
#   'WillowShoddy7846',
#   'Courtesyinch',
#   'rdocs',
#   'Personal_Job7151',
#   'IncorruptibleTruth',
#   'BrewHa34',
#   'aakkii911',
#   'Nihiliatis9',
#   'ruove',
#   'yutarson',
#   'Metool42',
#   'iLL135',
#   'EurekaStockade',
#   'HighFiveAssFuck',
#   'DancesWithCanoes',
#   'Fwob',
#   'Correct_Associate506',
#   'LarpoMARX',
#   'Tsavo43',
#   'AdolfSpongeMD',
#   'mafian911',
#   'TheHashassin',
#   'The_Ides_of_Hades',
#   'Kl0pp0s',
#   'Leznar',
#   'azazelthegoat',
#   'robbleshaver',
#   'manofkent79',
#   'NinjasOwnTheNight',
#   'test470',
#   'SexualDeth5quad',
#   'duncanmarshall',
#   'BladedDragon01',
#   'PVT_TT',
#   'HeyKid_HelpComputer',
#   'bub433',
#   'Yak-Electrical',
#   'turtleltrut',
#   'LumpyRevolution',
#   'shapu',
#   'didyoutestityourself',
#   'jmanTruthSeeker',
#   'ccrom',
#   'Clickonadsplz',
#   'SeiCalros',
#   'trumpdiego',
#   'tranceology3',
#   'going_for_a_wank',
#   'poorgermanguy',
#   'AcedDev',
#   'BarksAtIdiots',
#   'Quicklythoughtofname',
#   'TheOneFreeEngineer',
#   '2futuredck',
#   'jrgman42',
#   'Rocklobzta',
#   'ggqq',
#   'Mnmkd',
#   'K-Ziggy',
#   'Sour_Badger',
#   'Meastro44',
#   'fleegness',
#   'the_joy_of_VI',
#   'CurtisCFlushing',
#   'Cranial-Nerve',
#   'StanePantsen',
#   'snipes86',
#   'Bartley-Moss',
#   'TBFP_BOT',
#   'rook2pawn',
#   'OG_Bongo',
#   'MacMaizer',
#   'Animated_Ouranus',
#   'Old_Fart52',
#   'SlapMyCHOP',
#   'Rilauven',
#   'Leeysa',
#   'canman7373',
#   'LayerTasty',
#   'molasseass24',
#   'helloitismewhois',
#   'jmarseneault',
#   'Shanguerrilla',
#   'poopscarf',
#   'Hash_Is_Brown',
#   'RedClipperLighter',
#   'itspronouncedDRL',
#   'ARocketToMars',
#   'nalydpsycho'],
#  ['BinyaminDelta',
#   'AutoModerator',
#   'XxSpruce_MoosexX',
#   'Wrong-Paramedic7489',
#   'renaissancetrader',
#   'nevercleverer',
#   'groupthinkhivemind',
#   'SknotP524',
#   'Fatguy73',
#   'Natural-Born_Easman',
#   'fxrmxrphxb',
#   'FoggyBogHopper',
#   'Whittaker',
#   'banditorama',
#   'frugal_masturbater',
#   'StretchAncient8851',
#   'AgreeingWings25',
#   'RobotThatGoesOof',
#   'hangcorpdrugpushers',
#   'ihatelifetoo',
#   'EJohns1004',
#   '10sharks',
#   'TheTallMidget69',
#   'Savethelasttrap4me',
#   'rivensdale_17',
#   'TheNiteOw1',
#   'aiiryyyy',
#   'chris1096',
#   'Throwawaybibbi',
#   'ConkHeDoesIt',
#   'BackOnThrottle',
#   'Earthbjorn',
#   'KylesHandles',
#   'S-nner',
#   'forzion_no_mouse',
#   'urbeatagain',
#   'Ok_Presentation_5329',
#   'Freedomlover488',
#   'pootiemane',
#   'FullSidalNudity',
#   'CuomoKilledGma',
#   'Metalgrowler',
#   'StartingFresh2020',
#   'Crutation',
#   'Apetardo',
#   'Dadpockets',
#   'kanyesrevenge',
#   'Cornbread_Collins13',
#   'Dull-Heron-2036',
#   'Mediocrebutcoool',
#   'beater613',
#   'D-rad01',
#   'Step-Father_of_Lies',
#   'Maxwell-hill',
#   'Reaching4ThoseGrapes',
#   'AfterWorld08',
#   'Fatmouse84',
#   'WookerTBashington',
#   'alexm901',
#   'Dokthe2nd',
#   'StankyyyBut',
#   'dboy999',
#   'LoneHusky21',
#   'GMEbankrupt',
#   'pinkpenguin87',
#   'gk_red',
#   'Nac82',
#   'be-right-or-be-funny',
#   'cautiously_anxious',
#   'dontha3',
#   '69mmMayoCannon',
#   'OmegaOverlords',
#   'Johns_Mustache',
#   'Hoitaa',
#   'Lamelad19791979',
#   'IHateYuumi',
#   'RealiseADream',
#   'Average_Home_Boy',
#   'BillyBong333',
#   'Bbbbhazit',
#   'corrupt_mischief',
#   'el-cuko',
#   'Danger_Danger',
#   'gorimem',
#   'Dependent-Ad4448',
#   'Censorship_of_fools',
#   'megablast',
#   'Only-Treat7225',
#   'ReadingKing',
#   'Tellurian_Cyborg',
#   'dashmesh',
#   '_That_One_Fellow_',
#   'Blackcoat_Traitor',
#   'xiofar',
#   'TSKendrick',
#   'LePootPootJames',
#   'KelziCoN',
#   'StrangeNewRoads',
#   'Remote-Excitement849',
#   'guammm17',
#   'Kanderin',
#   'MTGO_Duderino',
#   'DovahkiinThuum',
#   'RedditIsTedious',
#   'jwg529',
#   'RickyTheRipper',
#   'home-and-auto',
#   'Bloodmark3',
#   'kccustom',
#   'Enough-Ad1242',
#   'safariite2',
#   '20hharri',
#   'A_Real_Patriot99',
#   'shrtsqzz',
#   'arnott',
#   'Hendrix1967',
#   'FriendlyPizzaPanda',
#   'Background-Bird6237',
#   'SargeMaximus',
#   'lolparty247',
#   'ra42ub',
#   'marshroanoke',
#   '#NAME?',
#   'VN1X',
#   'thebrinyocean',
#   'anon39316',
#   'Donuts_Are_Great',
#   'The_Last_Bassalope',
#   'gutteguttegut',
#   'ExtremeLeg',
#   'batmattman',
#   'Jolly-Payment2389',
#   'No_Driver_3386',
#   'Zylphhh',
#   'the_card_guy',
#   'bitempress',
#   'H-E-L-L-MaGGoT',
#   'ScurvsOnmeth',
#   'whitelightstorm',
#   'Other-Amount-6665',
#   'Pandorasbox64',
#   'maxwelka',
#   'nemoskullalt',
#   'DemiDivine',
#   'steve210sa',
#   'Jaisyjaysus69',
#   'lestofante',
#   'ConsciousFyah',
#   'Mikkelet',
#   'DefaultSubsAreTerrib',
#   'Footbuttzer',
#   'theliquidfan',
#   'IgnacioB3Jr',
#   'jeffsusername',
#   'BreakfastBros',
#   'eddymarkwards',
#   'droofe',
#   'Hammertime6689',
#   'FrankDrakman',
#   'Purplebuzz',
#   'snippysnapper23',
#   'Vanhelsing2020',
#   'SolarGrill',
#   'winpowguy',
#   'JazzlikeSpinach3',
#   'increbelle',
#   'Run_223',
#   'BrushfireSwany',
#   'MelodyOfMadness',
#   'Equivalent-Outside15',
#   'TimeForVengeance',
#   'Shaiya123',
#   'somedude-83',
#   'pbjars',
#   'Terrible-Paramedic35',
#   'jfarmwell123',
#   'WelcomeToTheFish',
#   'Working-Surround9788',
#   'orygunmane',
#   'roosters',
#   'OG_Bongo',
#   'borderlinebacon',
#   'flava_ADHD',
#   'AnyChallenge8829',
#   'Aggressive_Egg_9661',
#   'd20wilderness',
#   'cannaspiracy',
#   'Mka28',
#   'Street_Market7020',
#   'Ok-Entrepreneur-4466',
#   'Expert-Yesterday1255',
#   'Tinfoilhat14',
#   'The-Pissing-Panther',
#   'oak510boy',
#   'devilthedankdawg',
#   'ggqq',
#   'Midnightstimepasser',
#   'ghostCatcher23',
#   'bfiggie',
#   'PM_ME_NEW_VEGAS_MODS',
#   'ketoh78',
#   'dfieldhouse',
#   'wadakow',
#   'tuck8184',
#   'Bluezang',
#   'WoWLaw',
#   'Numerous_Image3061',
#   'ButterscotchNo1210',
#   '-The-Moon-Presence-',
#   'Its_Grex',
#   'ThaTruthHurts_',
#   'Empty_Sink_4597',
#   'KeifWellington22',
#   'Jack_Donaghy_Jr',
#   'PM_BIG_TIDDIES_PLS',
#   'xallsparkx905',
#   'jcalcerano',
#   'trumpscomingright4us',
#   'alienatedesire',
#   'Umber_Wall',
#   'redlion496',
#   'DaemonCRO',
#   'spunkyweazle',
#   'killflys',
#   'batacosta',
#   'YourGodIsEvil',
#   'snoaj',
#   'rusty_programmer',
#   'DukeOfGreenfield',
#   'K1LL_URSELF_RACIST',
#   'Brandy_Buck',
#   'clique34',
#   'Allmightyhastur',
#   'steIIarwind',
#   'vladivan',
#   'GroundedBeing',
#   'AxionGlock',
#   'IIIpercentFL',
#   'GRANDPA_FART_MUSTARD',
#   'jerrymp28',
#   'mr_lab_mouse',
#   'weirdmountain',
#   'Gringo0984',
#   'lboog423',
#   'JSwerve19',
#   'daxbr',
#   'BLACKxFR0STY',
#   'janxus',
#   'Daltron848',
#   'ItsSamObviously',
#   'K3R3G3',
#   'AlbertChomskystein',
#   'cleetdog101',
#   'Sparrow1989',
#   'puppiadog',
#   'MrNagasaki',
#   'twidlystix',
#   'MovieSock',
#   'XxNoResolutionxX',
#   'Theshepard42',
#   'amonamus',
#   'VegetableWord0',
#   'ahall331990',
#   'Adobo6',
#   'smakusdod',
#   'krusnik99',
#   'Infamous-Penalty-583',
#   'Osiris_Raphious',
#   'throwawaygamgra',
#   'slappyMcbappy',
#   'DallasDoll80',
#   'Significant-Bowl-737',
#   'squidgod2000',
#   'Few-Comment6124',
#   'Long_Ad8016',
#   'Mighty_L_LORT',
#   'West_Self',
#   'Nemo_Shadows',
#   'IndividualThoughts',
#   'TXreddest',
#   'Angy2021',
#   'Fudge_Correct',
#   'John_h_watson',
#   'ciphern',
#   'Pandainthecircus',
#   'iJacobes',
#   '_Proud_Banana_',
#   'headfaceperson',
#   'WayneDufty',
#   'TheDynamicKing',
#   'Many-Advantage-6792',
#   'mostardman',
#   'LlamaMadness420',
#   'troubledtimez',
#   'PeaceOfKake',
#   'johnnyd0808',
#   'Azuray2',
#   'TomCelery',
#   'slapmesomebass',
#   'Tiny-Construction425',
#   'PirateBlankFoul',
#   'BetterButter2021',
#   'UnluckyBag',
#   'SonOfTK421',
#   '__bad__SAM__',
#   'DDjr',
#   'Peglegsteve265',
#   'Kn0tnatural',
#   'islandtaco287',
#   'reddituser2501649',
#   'va_va_vigilante_voom',
#   'Apprehensive_Point11',
#   'Antlergoat',
#   'HighKeyedUp',
#   'Pianpianino',
#   'Several_Influence_47',
#   'Ivan_Jelical_429',
#   'Spaceboy80',
#   'EvilSporkOfDeath',
#   'Nevek_Green',
#   'OneNightStandKids',
#   'BobaMoBamba',
#   'Sensorshipment',
#   'Dumbestinvestor',
#   '1Cloudz9',
#   'Zer0_Tolerance_4Bull',
#   'Haredeenee',
#   'Otherwise-Dot3650',
#   'RegularConcern',
#   'DecktheHawls',
#   'eeLSDee',
#   'ConstructionDry9190',
#   'kalipede',
#   'gone11gone11',
#   'dankpants',
#   'adelie42',
#   'silentsights',
#   'Mahcrub424',
#   'dbargz',
#   'X761',
#   'awkwardpenguin20',
#   'zen88bot',
#   'cobeast',
#   'HunterGonzo',
#   'I_COULD_say',
#   '8last',
#   'redundancy2',
#   'DiabolicallyRandom',
#   'aquaponic',
#   'djbmelty',
#   'fyrefli666',
#   'experiento',
#   'point_nemo_',
#   'HomoFlaccidus',
#   'Partey_All_The_Time',
#   'Wunjo26',
#   'HaamerPoiss',
#   'mambomak',
#   '998n9o8909089-9901',
#   'noone569',
#   'Legitimate-Weird4758',
#   'MyCrispLettuce',
#   'anonradditor',
#   'ax255',
#   'horseradishking',
#   'sawftacos',
#   'lollytop',
#   'PrezzNotSure',
#   'Future_of_Amerika',
#   'REiiGN',
#   'reality_is_weird',
#   'JustATriHardCx',
#   'theskyalreadyfell217',
#   'Anyna-Meatall',
#   'lonewombat',
#   'coder0xff',
#   'jwrogers33',
#   'FnfHeat',
#   'not_Packsand',
#   'raleighs',
#   'HH_YoursTruly',
#   'goatchild',
#   'RideTillIDieFkr',
#   'GraniteMtn',
#   'zoltronzero',
#   'Due_Lion3875',
#   'jimi-ray-tesla',
#   'EpicCrisis2',
#   'Whisper06',
#   'Eternal-Testament',
#   'theartofbored',
#   'onlycatshere',
#   'bellini_scaramini',
#   'ataonfiree',
#   'LameEskimo',
#   'clexecute',
#   'TheGoalOfGoldFish',
#   'Ursomonie',
#   'trapqueen412',
#   'Ecstatic_Victory4784',
#   'unnecessarylad',
#   'niffler_egg',
#   'lurkenstine',
#   'jikae',
#   'Weird_Error_',
#   'Illustrious-Employ-5',
#   'TreeStumpKiller',
#   'writersfolly',
#   'GolfcartInjuries',
#   'OfficerLovesWell',
#   'monkeylovingape6969',
#   'Figg27',
#   'iwknights',
#   'FredBed489',
#   'LaggingEvolution3445',
#   'NEVERVAXXING',
#   'MooseFucker5000',
#   'Colt76Schilling',
#   'shpdg48',
#   'MustardTiger1337',
#   'portoroc86',
#   'Perciprius',
#   'cloudskip',
#   'Justjoinedstillcool',
#   'vwibrasivat',
#   'Legitimate_Finding44',
#   'R-Contini',
#   'massivecalvesbro',
#   'MJisANON',
#   'JAVACHIP1738',
#   'bigtimemoneybags',
#   'Cloud_Striker101',
#   'ShaohKahn',
#   'TheLastRedditUserID',
#   'bigdon802',
#   'covblues',
#   'phatz37',
#   'Dimethyleont',
#   'jasmine7098',
#   'wanderlust0314',
#   'Neauxluh',
#   'Any-Problem-7426',
#   'east_coast_eric',
#   'waverleyray',
#   'Aloysius1989',
#   'panawayne',
#   'satanicmannequin',
#   'koebelin',
#   'Beneficial-Pizza5911',
#   'DirectionLow357',
#   'Incredibly_Based',
#   'SamuraiEldenLord',
#   'ShivaDestroy',
#   'PsycheBreh',
#   'on3_3y3d_bunny',
#   'n0man0r',
#   'x-Sleepy',
#   'Emithenarc',
#   'gwilll',
#   'n0ts0subtle',
#   'Turd_HugeTaco',
#   'Lotsaa1',
#   'yutarson',
#   'droden',
#   'bH0LeZ',
#   'ICutDownTrees',
#   'EurekaStockade',
#   'JohnnyFlawless',
#   'mr_green',
#   'mentalrubixcube',
#   'Divinedragn4',
#   'LILilliterate',
#   'steelejt7',
#   'yamfood',
#   'dimebag42018750',
#   'lunar2solar',
#   'RompeChocha',
#   'tarponisalargefish',
#   'OverKill515',
#   'HashbeanSC2',
#   'CXgamer',
#   'Antivaxwhiteguy',
#   'TheSilentTitan',
#   'Chair_Toaster',
#   'Ok_Winner1682',
#   'studlyhungwell9',
#   'the_spruce_moose',
#   'torturetrilogy',
#   'magical_matey',
#   'AstronautRob',
#   'thewildcardbb1',
#   'Valance',
#   'Mnmsaregood',
#   'KrahzeefUkhar',
#   'Snookcatcher',
#   'AShipChandler',
#   'DiscipleOfYeshua',
#   'EZforme885',
#   'Shlimeeeeeeee',
#   'user_name1983',
#   'lovemykittiez',
#   'youvotedforthis12',
#   'l33tTA',
#   'ChipaGuazu',
#   'golfballthroughhose',
#   'Rapidz-Infinity',
#   'duane2020davis',
#   'pacmanpill',
#   'ThebigA321',
#   'Average_Dad_Dude',
#   'edinedm2021',
#   'zsmorris1',
#   'mediumsmallshirt',
#   'Crypto-efficient',
#   'ss1kp',
#   'TheBonusWings',
#   'King_Shami',
#   'pylmls',
#   'FannyJane',
#   'Skrapadelux',
#   'StableNo9555',
#   'jspike91',
#   'Bastardsblanket',
#   'greedycow776',
#   'StopAngerKitty',
#   'Axudicot',
#   'RemoveDear',
#   'LibertarianLola',
#   'sinistersouls3',
#   'dazza_bo',
#   'Put_It_All_On_Blck',
#   'OG_PapaSid',
#   'AbPerm',
#   'BitcoinBilli0naire',
#   'squidbi113',
#   'mffunmaker',
#   'angelfeet777',
#   'jaqueburn',
#   '80ninevision',
#   'DIGITALCITIZENSD',
#   'bman567',
#   'AcidicNature',
#   'Electronic_Trainer_4',
#   'Southern-Ad379',
#   'HighLows4life',
#   'Luihukulli',
#   'iKilluazoldyck',
#   'Hsizzle23745',
#   'Buick6NY',
#   'OilSlickRickRubin',
#   'mindboglin',
#   'markglas',
#   'teardrop082000',
#   'rantingsofastarseed',
#   'horseflydick',
#   'LimitSavings737',
#   'SirRichardHumblecock',
#   'A-SPAC_Rocky',
#   'IrvineKafka',
#   'hereholdthese',
#   'FloghornEgghorn',
#   'Indigo__Rising',
#   'timbengal1',
#   'HiIAmFromTheInternet',
#   'nessaavee',
#   'TrevaTheCleva',
#   'charlespenn1',
#   'kxxzy',
#   'lth5015',
#   'MadeToDisagree',
#   'MediumPhone',
#   'overthehilltotheleft',
#   'FightForTheSky',
#   'Gr1pp717',
#   'Sleepytreezz',
#   'Anxiouswalnuts',
#   'camerontbelt',
#   'Voodoosuppe',
#   'Sarah_Connor',
#   'toenailburglar',
#   'KeeperOfSpirit',
#   'wtbcd',
#   'Metroncat',
#   'PemaleBacon',
#   'Public_Fruit8058',
#   'GoldieCurlsGirl',
#   'Psychonaut2021',
#   'Royal_Fault4397',
#   'KorvaxNaniteJelly',
#   'im-not-a-bot-im-real',
#   'Fragrant-Progress-32',
#   'watchingitallcomedow',
#   'FREE-AOL-CDS',
#   'Fabulous-Row397',
#   'Bubbly-Bat-7869',
#   'pancakes3921',
#   'olymp1a',
#   'joltzspinz',
#   'truculentt',
#   'If1984Then1776',
#   'Ricky_gervaisIRL',
#   'eloooooooo',
#   'Shington501',
#   'slackator',
#   'Whisker-B',
#   'Brandycane1983',
#   'Wmd4lunchh',
#   'ThePopeofHell',
#   'Br0k3n-T0y',
#   'Brave-Victory-3632',
#   'firestorm64',
#   'TheDinkleberg',
#   'Ape_McNanners',
#   'Drortmeyer2017',
#   'pwnedkiller',
#   'hi_im_4est',
#   'Died-Last-Night',
#   'MeanieMem0',
#   'bleszt',
#   'Tantalus4200',
#   'Living-Stranger',
#   'Tes420',
#   'Impossible-Ad-9573',
#   'scottard',
#   'colonelgoatfucker',
#   'Shiroi_Kage',
#   '_________FU_________',
#   'gn4rw0lph',
#   'LazyThing9000',
#   'RikiSanchez',
#   'TRDBG',
#   'Cautionzombie',
#   'Euphoric_Bass_1419',
#   'tarapj',
#   'rashpoutine',
#   '_HagbardCeline',
#   'PoetOfLight',
#   'AuraBlazeOfficial',
#   'FragMeNot',
#   'ChrisWinterTBE',
#   'Useful-Bookkeeper264',
#   'DavarDavarius',
#   'SolidAd2342',
#   'jeekaiy',
#   'funkmasternick',
#   'Gaxsquatch',
#   'Calierio',
#   'Jkleezy1234',
#   'Overlord1241',
#   'Just_Learned_2_Dance',
#   'throwaway12fuckyou',
#   'Withyourfeetintheair',
#   'partytime71',
#   'pollocrudo',
#   'anallman',
#   'Death_is_real',
#   'chainmailbill',
#   'JoeSicko',
#   'Rodrigo669',
#   'Hamogany',
#   'cosmufc',
#   'nerveclinic',
#   'Wild_Frosting_5353',
#   'RiseOfTheAlts',
#   'chillantino',
#   'Noiseyeyeballs',
#   'SockMaximum',
#   'MeLittleSKS',
#   'iceyorangejuice',
#   'bullfrog316',
#   'Barry_Balzak',
#   'hoesindifareacodes',
#   '_Benny_Lava',
#   'AntiSocialBlogger',
#   'IntoTheLight43',
#   'Freeman_Goldshonnie',
#   'Flyingheelhook',
#   'Idcr1Z1s',
#   'AquaPixelzzz',
#   'bigpumprun',
#   'Latin-Danzig',
#   'Anarchystocks',
#   'Baramos_',
#   'foreycorf',
#   'likesmountains',
#   'Less-Veterinarian-63',
#   'lraynor6',
#   'Yattiel',
#   'QuartzPuffyStar',
#   'tomas_diaz',
#   'thellllvirtuoso',
#   'howigottomemphis',
#   'anon_lurk',
#   'Kami-no-dansei',
#   'fartknocker369',
#   'lucabeats',
#   'Crypto_Creeper420',
#   'JoltinJeff',
#   'sonicb00m42',
#   'slayerofgods615',
#   'godblow',
#   'MrMarmot',
#   'sandiegophoto',
#   'Gloworm02',
#   'Jayken',
#   'hobo131',
#   'blueandgold777',
#   'OGWeedKiller',
#   '2legit2quit84',
#   'DontCareWontGank',
#   'empiricalreddit',
#   'Nirvana038',
#   'alhernz95',
#   'pieinfaceisgoodpie',
#   'AdamSkeez',
#   'Lelfah204',
#   'scarymoose',
#   'Krakov92',
#   'voodoodog_nsh',
#   'DarthFrancis9',
#   'Schippsahoy',
#   'Re4Myrrh',
#   'jvanzandd',
#   'Bearwaze',
#   'AdministrativeMost45',
#   'Enough_Region_7641',
#   'tim2k000',
#   'ScarPersonal',
#   'CurryBoy420',
#   'KillRoyTNT',
#   'StriKyleder',
#   'sublimek99',
#   'frostwolf18',
#   'bryty93',
#   'ozfactor1',
#   'Laotzeiscool',
#   'Atudeofmyown',
#   'Image_Inevitable',
#   'mikess484',
#   'WolandPT',
#   'Jnoles07',
#   'matishg',
#   'beeplantlady',
#   'deadrozegrl',
#   'CryWinter8487',
#   'Kyburgboy',
#   'toterengel367',
#   'SupahBlue',
#   'not-the-fake-DG',
#   'selphmedicated',
#   'moistlysweatyy',
#   'mrfishy8436',
#   'Deganawida33',
#   'volcanic_birth',
#   'AdamSmith4206',
#   'SpaMcGee',
#   'Joy_McClure',
#   'CharacterRoad359',
#   'UrMouthsMyShithole',
#   'ProbablyHighOhwell',
#   'Buffalolife420',
#   'dobermannbjj84',
#   'SanctusUltor',
#   'radrun84',
#   'kgrace1123',
#   'Tedious-aggression',
#   'RainbowDolphin95',
#   'worktheshoot',
#   'tendlos',
#   'me_team',
#   'Macontrera217',
#   'anotherblankcheck',
#   '123456American',
#   'AyatollahChobani',
#   'yutfree',
#   'innerpurification',
#   'cocolulu2',
#   'Kirby_hill8245',
#   'cxh502133',
#   'Otherwise-Fox-2482',
#   'turnipwine',
#   'karmigiano',
#   'DubDeuceInThisBih',
#   'PsychonautDad',
#   'Boston__Massacre',
#   'LTGeneralGenitals',
#   'meiso',
#   'Ok-Lychee6612',
#   'berettaswag',
#   'Archangel1313',
#   'staticrave',
#   'loose-leaf-paper',
#   'dkentl',
#   'CPT_JUGGERNAUT',
#   'captaindata1701',
#   'Scitz0',
#   'Gnarmsayin',
#   'Brain_f4rt',
#   'WWWTT2_0',
#   'aznology',
#   'Familiar-Luck8805',
#   'Segundaleydenewtonnn',
#   'KevlarD-',
#   'BlueDreamEvil',
#   'BigPapa1998',
#   'SadakoSales',
#   'chasinglivechicken',
#   'Atcollins1993',
#   'theNoodle162',
#   'bygtopp',
#   'Winnardairshows',
#   'xwarslayerx',
#   'klitmania',
#   'SomeAnonAssface',
#   'Exempty',
#   'Hiddensmegmawarrior',
#   'RentedPineapple',
#   'WalterBlackness',
#   'KingCrow27',
#   'WorldWideDarts',
#   'blue-moves',
#   'Slenthik',
#   'BaroqueBunny',
#   'habitabo_veritate',
#   'Positive_Slight',
#   'earthboundmissfit',
#   'numonestun',
#   'drewadams5812',
#   'danimal0204',
#   'Ominojacu1',
#   'yum3no',
#   'fubooze',
#   'audiavant86',
#   'waybetter94',
#   'The_Frag_Man',
#   'crzdcarney',
#   'Mentos13371',
#   'NYR4',
#   'SooooooMeta',
#   'electron65',
#   'mikenice1',
#   '__Sentient_Fedora__',
#   'Difficult_Quantity12',
#   'raggaebanana',
#   'xxRonzillaxx',
#   'real_psymansays',
#   'FapingAGoGo',
#   'intheloop76',
#   'BigZwigs',
#   'FirstYouNeedToGetMad',
#   'mgick999',
#   'wildraft1',
#   'mohamedsmithlee',
#   'queefiest',
#   'andthatswhathappened',
#   'Rude_Journalist',
#   'RhaegaRRRR',
#   'TheDiamondsSystem',
#   'BigWeenie45',
#   'TheCarstard',
#   'Seagoon_Memoirs',
#   'No-Contribution-1312',
#   'Mediocre-Ad8967',
#   'Banalfarmer-goldhnds',
#   'molecat1',
#   'Considered_Dissent',
#   'One-Among_The-Fence',
#   'TheIronMoose',
#   'Rudyard_Hipling',
#   'General_Complaint_86',
#   'JakeWombat',
#   'Jared_Kincaid_001',
#   'Magnanimous-',
#   'WonWop',
#   'Live-Mail-7142',
#   'theonewhostaresback',
#   'fdp137',
#   'SchloomyPops',
#   'Mamalocs',
#   'BonelessSkinless',
#   'Ronnie_1990',
#   'Positive-Capital',
#   'HonorTheAllFather',
#   'CollegeMiddle6841',
#   'Whispering-Depths',
#   'poopsiedaisy2',
#   'crisps_ahoy',
#   'KFoxtrotWhiskey',
#   'agprincess',
#   'BaldrTheGood',
#   'Gyoel',
#   'ReadRightRed99',
#   'dickdiggler911',
#   'borchnsuch',
#   'PlzDownvoteMeTuffGuy',
#   'Shiny_Shedinja',
#   'Pongfarang',
#   'LuluLaRue1',
#   'Mortara',
#   'NoRegrets-518',
#   'UltraN64',
#   'Incoherentp00rnoises',
#   'dethmaul',
#   'Wapata',
#   'thelehmanlip',
#   'tcarr1320',
#   'djohn111',
#   'seancm32',
#   'WinterSoldierXX',
#   'SuperSaiyanNoob',
#   'TheFreeman148',
#   'Iamabenevolentgod',
#   'MemphisThePai',
#   'taylorpagemusic',
#   'bluemanoftheyear',
#   'PM_ME_YOUR_SUNSHINE',
#   'skywalkerr69',
#   'SwiftDeathPunch',
#   'ihaveacoupon',
#   'Logical_Photograph_1',
#   'kepp89',
#   'GaintBowman',
#   'DuneWulff',
#   'ApexxPredditor',
#   'KaTie882',
#   'CaptKeef',
#   'tbariusTFE',
#   'im_a_hufflepuff_',
#   'No1Mystery',
#   'PusherRed88',
#   'HotshotPatriot17',
#   'Cleveland_Guardians',
#   'QuarantineSucksALot',
#   'TheIronGus',
#   'vynusmagnus',
#   'Truffluscious',
#   'Fantastic-Mess',
#   'Herbalmami',
#   'DoctorShlomo',
#   'Mrsocko95',
#   'immenselysleek',
#   'signewton',
#   'EmbryonatedX',
#   'heave20',
#   'Money-Driver-7534',
#   'Vosk500',
#   'VegetableInjury1537',
#   'Kiokochat',
#   'amIhighbro',
#   'AnfarwolColo',
#   'FiestaDonkey',
#   'prototorpedo',
#   'Karma-bangs',
#   'xCELTICxFROSTx',
#   'slowerisbetter527',
#   'CaptainAntwat',
#   'Drizen',
#   'GenerationZ3RO',
#   'arkayydia',
#   'Iagi',
#   'cosmicdances',
#   'RockOx290',
#   'o3mta3o',
#   'WhoStoleMyPassport',
#   'BocaSeniorsWsM',
#   'Hotspur000',
#   'flyingdinosaur99',
#   'makasuandore47',
#   'motherflower3',
#   'trezenx',
#   'Necessary-Window5649',
#   'WildBill598',
#   'ZippZappZippty',
#   'robanthonydon',
#   'implyingiusereddit',
#   'The_loudspeaker721',
#   'BubblyPlace',
#   'Sifar666',
#   'Extre',
#   'Monkey-Munden',
#   'JDLKC',
#   'PleaseFartOnMyFace',
#   'Filthschwein',
#   'FikseStang',
#   'b1gp15t0n5',
#   'clean-it-up',
#   'fakeworld112',
#   'LePetitVoluntaire',
#   'TheMagicWheel',
#   'cniese5',
#   'EhMapleMoose',
#   'Lazaruz5150',
#   'Emotional-Border-339',
#   'Donahue-Industry',
#   'Captainshark98',
#   'slowburningrage',
#   'FidelHimself',
#   'Louloush123',
#   'wombatnoodles',
#   'BananaStand511',
#   ...],
#  ['bichonista',
#   'dunnkw',
#   'kingmoobot',
#   'BloopityBlue',
#   'Alemaya34',
#   'Greenmarineisbak',
#   'Realistic-Demand-615',
#   'pipsdontsqueak',
#   'honkballs',
#   'Standgeblasen',
#   'backupJM',
#   'geiwne',
#   'ThrowThemUnderTheBus',
#   'ChairOwn118',
#   'baquish',
#   'PreviouslyBannedXD',
#   'NihilistPunk69',
#   'Yisshyo',
#   'Downtown-Cover-2956',
#   'iDontKnowBro2020',
#   'High_Ground_Sand',
#   'CyberArtillery',
#   'absolute_zenologia',
#   'GabrielNathaniel',
#   'ArcticRedwood',
#   'Llama_Sandwich',
#   'LieutenantW0rf',
#   'gor8884',
#   'too-legit-to-quit',
#   'Micky-OMick'],
#  ['bichonista',
#   '3.32299E+13',
#   'PeopleCanBeThisDumb',
#   'lordatomosk',
#   'MuuaadDib',
#   'ResponsibleHall9713',
#   'TubularStars',
#   'ram921',
#   'ophiusca',
#   'Greenthund3r',
#   'coroyo70',
#   'Wooden_Water_8547',
#   'MadKingTyler',
#   'cardanolovelace',
#   'YoBuddyGuyHey',
#   'dunnkw',
#   'Setsuna85',
#   'mlime18',
#   'Taekwondista',
#   'MWF123',
#   'xworfx',
#   'Zetin24-55',
#   'Slappamedoo',
#   'eifersucht12a',
#   'salex100m',
#   'DagothWSB',
#   'league_of_otters',
#   'Spiffiestspaceman',
#   'AngelaMotorman',
#   'MadChild2033',
#   'Duke-of-Limbs',
#   'Miserable-Couple893',
#   'abraksis747',
#   'Dalejrman',
#   'captdoug137',
#   'wpgjets73',
#   'riplikash',
#   'Aureus23',
#   'kaiyoukhan',
#   'SathedIT',
#   'kalirion',
#   'Euphoric_Promotion85',
#   'JohnnyBgood420',
#   'user_bits',
#   'ScyllaIsBea',
#   'autotldr',
#   'ambigrammer',
#   'Unique_name256',
#   'vas-is-boss',
#   'haysanatar',
#   'dergster',
#   'melperz',
#   'existentialepicure',
#   'lonestar34',
#   'zomboromcom',
#   'irsocali',
#   'Aelarr',
#   'Dizzy_Blacksmith_165',
#   'MyGodItsFullofScars',
#   'mind_on_crypto',
#   '-Great-Scott-',
#   'RugBurnDogDick',
#   'Steve_warsaw',
#   'spicycucumberz',
#   'kingmoobot',
#   'RP_Bear9',
#   'echofactory',
#   'WestPastEast',
#   'Shreddershane90',
#   'Eastern_Talk_2078',
#   'Drummer_23',
#   'Tasty-Flamingo-6592',
#   'Zevvion',
#   'bear_2167',
#   'CaptainKompromat',
#   'HotMachine9',
#   'Diligent-Cat3216',
#   'DrVagax',
#   'XedricDeCalb',
#   'madmax435',
#   'ChapitoDito',
#   'blay12',
#   'Mav986',
#   'YugeFrigginGoy',
#   'ChristianZardum_0001',
#   'Rhondabobonda20',
#   'Xp717',
#   'KnightRiders7',
#   'imrduckington',
#   'The42ndDuck',
#   'AdOrganic3138',
#   'tissiboi',
#   'blindreefer',
#   'Karnivoris',
#   'SimplePerson326',
#   'WeedInTheKoolaid',
#   'OilyBuilding',
#   'skredditt',
#   'TacticalChimichanga',
#   'CodyJProductions',
#   'BloopityBlue',
#   'JustMadeTheList',
#   'A100921',
#   'kaydogbrawls',
#   'RealExii',
#   'Bmustapha14',
#   'JuhuIBabu',
#   'ClemiHW',
#   'mgphotogirl',
#   'jk583940',
#   'free_based_potato',
#   '1920-1945',
#   'LD300',
#   'Cooljay22222',
#   'Basicallyvwlover80',
#   'babababuttdog',
#   'AdminScales1155',
#   'DeMonstaMan',
#   'klsyndrome',
#   'stillbeat8',
#   'dannyjokes1',
#   'enakj',
#   'freckledgreen',
#   'Individual_Owl7773',
#   'Salad_Guru',
#   'pgriffin70',
#   'collegiateofzed',
#   'BrickMom',
#   'dlax141',
#   'belzir91',
#   'EepeesJ1',
#   'Man_AMA',
#   'CamelCash000',
#   'Cimb0m',
#   'CrunchyAl',
#   'FYouRussianWarship',
#   'A_bowl_of_porridge',
#   'Justapilot13',
#   'morenewsat11',
#   'Evo_8urV8',
#   'twotwo_twentytwo',
#   'Thedrunner2',
#   'Fistyerbutt',
#   'shaainXoverlord',
#   'vulcanxnoob',
#   'Willardwarrior1',
#   'lcecoffee12',
#   '_Kofiko',
#   'GuiltySubstance9428',
#   'fuber',
#   'Dmore79',
#   'illacudasucks',
#   'WindHero',
#   'Uncutdix',
#   'Skimbla',
#   '_SwiftDeath',
#   'WokeupFromsleep',
#   'human_stuff',
#   'Ronv5151',
#   'imanAholebutimfunny',
#   'ttynot',
#   'ironfunk67',
#   'CursedLemon',
#   'maineblackbear',
#   'examiner007',
#   'DzezGt',
#   'rockguitardude',
#   'Flat_Bodybuilder_175',
#   'Quotizmo',
#   'Lord_fuff',
#   'herooftime7',
#   'WoodpeckerFull1403',
#   'clhines4',
#   'BackAlleyKittens',
#   'Hellbounder304',
#   'escabean',
#   'Draiko',
#   'The_Queef_of_England',
#   'segasega89',
#   'notataco007',
#   'xkmasada',
#   'Killface55',
#   'Cultural-Estimate768',
#   'WholesaleBacon',
#   'jakehood47',
#   'b-napp',
#   'Dogggggle',
#   'BariNgozi',
#   'Xenjael',
#   'aerospacemonkey',
#   'dutchmetalhead17',
#   'No-Armadillo7693',
#   'Unlikely-Sell6476',
#   'Bad_Prophet',
#   'FlusteredKelso',
#   'Zestyclose_Meet1034',
#   'mentnomore',
#   'eanoper',
#   'Fleegalicious',
#   '_notsuoh_',
#   'Heelgod',
#   'Bl4ckb100d',
#   'Touge_Monster',
#   'maaseru',
#   'cnest777',
#   'MrSparkyBean',
#   'Hopeful_Search3729',
#   'ApeCrusher',
#   'lo0ilo0ilo0i',
#   'AAmell',
#   'toolsoftheincomptnt',
#   'Phoenix1294',
#   'Zeldaisafunseries',
#   'johnfarmingdale',
#   'Arachnatron',
#   'sporeegg',
#   'davesreddit123',
#   '11th-plague',
#   'BlueFalconPunch',
#   'Lonelan',
#   'SwisherUnsweet',
#   'CBNM',
#   'Hidden-Wisdom',
#   'JarOfMayo2020',
#   'filler-content',
#   'SirLionhearted',
#   'BobDylanBlues',
#   'PissedOffChef',
#   'theillustratedlife',
#   'Tek_Support_Guru',
#   'Tyrant_R3x',
#   'sardinesforever',
#   'pope_hilarious',
#   'Craft_suds',
#   'Affectionate-Tree842',
#   'Misterwuss',
#   '____DEAFPOOL____',
#   'SurealGod',
#   'Jsully23',
#   'happylamp01',
#   'Please_Label_NSFW',
#   'kultigsptrizigfrisch',
#   'Low-Bet305',
#   'DesperateImpression6',
#   'TheXypris',
#   'cosmin_c',
#   'Agoodlittleboy',
#   'DoYaLikeBeans',
#   'fordtp7',
#   'FrootLoop23',
#   '4dailyuseonly',
#   'Sexy_Apocalypse',
#   'Scrapalicious',
#   'NewbHunter19',
#   'thebankroll',
#   'Turboswag420',
#   'Uncertain_Sage',
#   'simple-potato-farmer',
#   'jaded68',
#   'WastL337',
#   'Parush9',
#   'Mahaloth',
#   'Gitdagreen',
#   'Fairycharmd',
#   'dismissivewankmotion',
#   'rhole50',
#   'Original_Shovel',
#   'abletofable',
#   'RampantPrototyping',
#   'lepobz',
#   'HellknowsJS',
#   'NahImSerious',
#   'SexyTimeDoe',
#   'MulchyYT',
#   'aregularNYguy',
#   'TobacoeJuice',
#   'Snap_Zoom',
#   'jasimon2',
#   'Mountain-Homework299',
#   'IrishRogue3',
#   'ExternalMongoose9251',
#   'bookmaster1',
#   'McFeely_Smackup',
#   'MyCleverNewName',
#   'Needless-To-Say',
#   'fathertime99',
#   'kmagsy',
#   'JaesonBee',
#   'Zero916',
#   'Foolazul',
#   'stevenbrotzel91',
#   'SirThatsCuba',
#   'Tr0way',
#   'Rec_desk_phone',
#   'Freddo03',
#   'tastymud6809',
#   'LeftIsBest-Tsuga',
#   'JJ954',
#   'BlueBlood75',
#   'jaird30',
#   'kolembo',
#   'Alemaya34',
#   'Superb_Health9413',
#   'ChristianSaves',
#   'TheGreyOne889',
#   'ohitsbri',
#   'sdw90808',
#   'devxxz',
#   'Nomadatic818',
#   'Bulliwyf',
#   'maxpower666',
#   'GrassApe',
#   'Byte_Fantail',
#   'Dark_Vengence',
#   'Coldspark824',
#   'desertgemintherough',
#   'E_PunnyMous',
#   'GO2462',
#   'Affectionate_Gas3623',
#   'SnatchasaurusRex',
#   'fascinat3d',
#   'Stocky2020',
#   'SlappedByKarma',
#   'awwaygirl',
#   'TheGreatLordOfDance',
#   'medinian',
#   'anayaham',
#   'mriv70',
#   'ruffsnap',
#   'Ironclad001',
#   'gintoddic',
#   'Iampepeu',
#   'Southboundthylacine',
#   'SparksWatch51',
#   'TheGreasyCigarette',
#   'Big_Honeydew6225',
#   'yoteyote3000',
#   'giu_1',
#   'Klingolol',
#   'ProfessionalRecord97',
#   'cassiopeia8212',
#   'PhillySpecial2424',
#   'General_Tarzan',
#   'lalalalikethis',
#   'neutralityparty',
#   'Super_Bath2626',
#   'MDtrades1',
#   'Mrkyle1984',
#   'tvcky69',
#   'SunsetBro78',
#   'GeorgeWendt1',
#   'AyVePe',
#   'PepeRoni6969',
#   'AnyMain',
#   'Anxious_Plum_5818',
#   'ebelnap',
#   'psychotica1',
#   'nothinnews',
#   'meaghancates22',
#   'nerdyframer',
#   'Sevans1223',
#   'CaptainSolo_',
#   'post_angst',
#   'Salvatoris',
#   'OrdinaryBartender',
#   'Donzo_banks',
#   'DustTasty',
#   'Frank_Bunny87',
#   'Saomd',
#   'Crashtag',
#   'Ubersupersloth',
#   'Bathroomious',
#   'willybestbuy86',
#   'hdhwhshdhdhwvwixudg',
#   'F1iceman',
#   'chaoseincarnate',
#   'aMaG1CaLmAnG1Na',
#   'FreshInvestment_',
#   'MAIRJ23',
#   'Reddead67',
#   'ReversedTimeMachine',
#   'TheAmishPhysicist',
#   'iron_minstrel',
#   'crazykentucky',
#   'sadandshy',
#   'tlewallen',
#   'guitarguy1685',
#   'gustavocabras',
#   'greythicv',
#   '12kgun84',
#   'abraxart',
#   'r3asonable_thinker',
#   'justredditinit',
#   'Wanderer2109',
#   'AyatollahChobani',
#   'Buttercup23nz',
#   'German_1945',
#   'GummoNation',
#   'Sportfreunde',
#   'ApprehensiveGlove587',
#   'Obeywithcaution413',
#   'Yugan-Dali',
#   'MajesticSunflower48',
#   '3choplex',
#   'gmoney910',
#   'yoshilovescookies',
#   'weewilliwilson',
#   'TyroneLeinster',
#   'fried_eggs_and_ham',
#   'ExistentialistMonkey',
#   'rxdrug',
#   'Mattrockj',
#   'fuck_your_new2',
#   'AlgebraicIceKing',
#   'Trophy-Husband1',
#   'tjsr',
#   'disposable_account01',
#   'cupcakesgirlie7',
#   'follow-48',
#   'bre1110',
#   'Murdercorn',
#   'polishedninja7',
#   'jsheppy16',
#   'liquidpictureframes',
#   'jiakpapa',
#   'Alandicasio',
#   'bicisfrench',
#   'Summebride',
# ...
#   'PsychLegalMind',
#   'Markdd8',
#   'Epistaxis',
#   'zimm0who0net',
#   'Triumph807',
#   'ikaros-1',
#   'Ancquar',
#   'dishonestdick',
#   'ConsitutionalHistory',
#   'Worldly-Novel-7123',
#   'TheToastIsBlue',
#   'sixfootskunkplant',
#   'RobberRedford',
#   'Dromeus01',
#   'warwasbeginning',
#   'BCSWowbagger2',
#   'Intrepid_Method_',
#   'LawHelmet',
#   'yanman',
#   'o11c',
#   'PositiveWestern',
#   'thebigham1',
#   'SerendipitySue',
#   'compstomper1',
#   'DorkJedi',
#   'icearrowx',
#   'WaltKerman',
#   'to_change',
#   'I_call_Shennanigans_',
#   'Kamwind',
#   'Schoritzobandit',
#   'PoliteAndPerverse',
#   'AtenderhistoryinrusT',
#   'CaptainKiddFucker',
#   'ShamelesslyPlugged',
#   'matthewwehttam',
#   'spicytacocat',
#   'ssbmhero',
#   'zincpl',
#   'Supergun1',
#   'The_Band_Geek',
#   'tyboxer87',
#   'ElFuddLe',
#   'The_Good_Count',
#   'ManBearScientist',
#   'Aphix',
#   'naomika_iwafumi',
#   '69_OClock_',
#   'PhillyTaco',
#   'cheunste',
#   'BearDick',
#   'jrf_1973',
#   'VVillyD',
#   'nemoomen',
#   'oren0',
#   'Jaaawsh',
#   'KnowsAboutMath',
#   'Bovey',
#   'Targren',
#   'wiithepiiple',
#   'Lan098',
#   'GhostOfJamesRandi',
#   'prkskier',
#   'Craftycoco',
#   'triangle60',
#   'IcedAndCorrected',
#   'Delta_Tea',
#   'scstraus',
#   'Stepan-01',
#   'gonzoforpresident',
#   'PairOfMonocles2',
#   'Darsint',
#   'breakingb0b',
#   'hurffurf',
#   'marklein',
#   'pileofpukey',
#   'Hemingwavy',
#   'sephstorm',
#   'awesomefutureperfect',
#   'Volomon',
#   'thesugardealers',
#   'salynch',
#   'Will_Smith_Puppet',
#   'GameEnders10',
#   'rdinsb',
#   'lulfas',
#   'Aggregate_Browser',
#   'taldarus',
#   'PM_me_Henrika',
#   'JONO202',
#   'brainpower4',
#   'sam_likes_beagles',
#   'djphan2525',
#   'ProfessionalWonder65',
#   'zeperf',
#   'xao184',
#   'jayrocksd',
#   'CotswoldP',
#   'CrazyStrawHobbyist',
#   'gaoshan',
#   'Notengosilla',
#   'ThatFuzzyBastard',
#   'Pndwavy1',
#   'HotOden',
#   'dresserplate',
#   'gashgoldvermilion',
#   'n00py',
#   'perrycarter',
#   'unclenoriega',
#   'kormer',
#   'MaybePenisTomorrow',
#   'InitiatePenguin',
#   'da96whynot',
#   'SFepicure',
#   'cowvin',
#   'RoundSimbacca',
#   'roflz',
#   'BrasilianEngineer',
#   'DocMerlin',
#   'picardo85',
#   'patjohbra',
#   'dangerzone2',
#   'duck_one',
#   'got_nations',
#   'bl1y',
#   'Yellow_Snow_Cones',
#   'beanbootzz',
#   'rtechie1',
#   'docyande',
#   'JuicedCardinal',
#   'crackercider',
#   'Nama__Jeff',
#   'hwagoolio',
#   'Brilliant-Parking359',
#   'craigeryjohn',
#   'srbarker15',
#   'GPareyouwithmoi',
#   'sir_mrej',
#   'HollywoodTK',
#   'holographoc',
#   'jadnich',
#   'chinmakes5',
#   'JLeeSaxon',
#   'EatTrainCode',
#   'Bizarre_Protuberance',
#   'IsThatAll',
#   'BezugssystemCH1903',
#   't_mo',
#   'InTooDeepButICanSwim',
#   'B0h1c4',
#   'Zyxer22',
#   'lemmonquaaludes',
#   'unkz',
#   'Ok-Wall9646',
#   'naidim',
#   'Hellbear',
#   'tjdavids',
#   'ScribebyTrade',
#   'SloppyMeathole',
#   'monocasa',
#   'CaffeineFor500',
#   'EasywayScissors',
#   'robo-walrus',
#   'throwaway12junk',
#   'rketz',
#   'provider305',
#   'baad_bh',
#   'zachalicious',
#   'countrykev',
#   'qoou',
#   'lokujj',
#   'ArcticRiot',
#   'bibliophile785',
#   'cleverSkies',
#   'friend1949',
#   'swiftessence',
#   'teacherofderp',
#   'metalski',
#   'stupendousman',
#   'JamieOvechkin',
#   'RandomDudeYouKnow',
#   'YaBoiJim777',
#   'boisepmthrowaway',
#   'definitelyjoking',
#   'iamagainstit',
#   'Xaxxon',
#   'PoisonMind',
#   'dircs',
#   'TapedeckNinja',
#   'HookersAreTrueLove',
#   'pyrrhios',
#   'Aratar2011',
#   'thewimsey',
#   'BeauteousMaximus',
#   'KennesawMtnLandis',
#   'historyteacher48',
#   'Pied_Piper_',
#   'Rheastar',
#   'ClockOfTheLongNow',
#   'morechatter',
#   'adkayaker',
#   'BarelyLingeringWords',
#   'CaptainofChaos',
#   'Remixer96',
#   'lunarNex',
#   'thehappyhobo',
#   'drdan82408a',
#   'langeajames',
#   'LittleRush6268',
#   'Pdb39',
#   'a1tb1t',
#   'taw',
#   'PolicyWonka',
#   'RotaryJihad',
#   'podnito',
#   'wenzlo_more_wine',
#   'spacechimp',
#   'AdKind5428',
#   'OMG_GOP_WTF',
#   'Novel_Amoeba7007',
#   'bballdadof3',
#   'IWANNALIVEEEEE',
#   'paulsmt',
#   'Paumanok',
#   'SmokeGSU',
#   '0x90Sleds',
#   'emprahsFury',
#   'Aubdasi',
#   'deltabagel',
#   'PaddedPews',
#   'Dookiet',
#   'jaw0012',
#   'orthros',
#   'MrOaiki',
#   'ExceptionCollection',
#   'Xero03',
#   'Leightonian',
#   'Oranos2115',
#   'PlugToEquity',
#   'alexsdad87',
#   '5000DollarSuitComeOn',
#   'elrobolobo',
#   'stubble3417',
#   'meteoraln',
#   'SquaredCubic',
#   'DocTam',
#   'thelyfeaquatic',
#   'Dan_From_Japan',
#   'MundaneConclusion82',
#   'sciencecritical',
#   'EvelynIsReal',
#   'Head-Mastodon',
#   'au-smurf',
#   'Vasastan1',
#   'ytnthrhmn',
#   'EagleOfMay',
#   'pconrad97',
#   'Dicebar',
#   'officerevening',
#   'CynDoS',
#   'BrexitBlaze',
#   'HotDamn18V',
#   'tevert',
#   'froggerslogger',
#   'Friesennerz',
#   'lake_whale',
#   'no-name-here',
#   'Ilverin',
#   'ElderKingpin',
#   'NoRexTreX',
#   'Vesoom',
#   'ersogoth',
#   'indispensability',
#   'Thoguth',
#   'Nadieestaaqui',
#   'no_buses',
#   'Runaway42',
#   'Renegade_Meister',
#   'netdance',
#   'joedartonthejoedart',
#   'nateberkopec',
#   'Moohog86',
#   'SanDiegoJuiJitsu',
#   'SleepyMonkey7',
#   'king_rensselaer',
#   'tomrlutong',
#   'peacefinder',
#   'osprofool',
#   'Fando1234',
#   'foolishballz',
#   'Germaine8',
#   'higherbrow',
#   'chickenonthehill559',
#   'Astro3840',
#   'MemberOfMautenGroup',
#   'Jorsturi',
#   'JustCallMeBen',
#   'engi_nerd',
#   'multicolored_logic',
#   'kaeroku',
#   'DarkJester89',
#   'PuffyPanda200',
#   'shs0007',
#   'WhoopingWillow',
#   'Bank_Gothic',
#   'd0s4gw',
#   'Try_Number_8',
#   'ChemistryFan29',
#   'extrahardrock',
#   '_YonderMountain',
#   'sexapotamus',
#   'gecon',
#   'Ruar35',
#   'dozenspileofash',
#   'zdayatk',
#   'xrimane',
#   'RihanCastel',
#   'Automatic-Concert-62',
#   'mwknight',
#   'scullys_alien_baby',
#   'Collegenoob',
#   'ImperialAuditor',
#   'TransposingJons',
#   'gurmag',
#   'Werv',
#   'unnamed_elder_entity',
#   'digbyforever',
#   'ricerking13',
#   'skurvecchio',
#   'Jaran',
#   'buckykat',
#   'tbonetexan',
#   '1SilentWarrior',
#   'NSNick',
#   'Segundo-Sol',
#   'urbansasquatchNC',
#   'FakDendor',
#   'tklite',
#   'chiara987',
#   'Cincinatus_Barbatos',
#   'tkc80',
#   'shaokim',
#   'MarSword_T',
#   '_JohnJacob',
#   'Cardsfan961',
#   'lycanter',
#   'd36williams',
#   'h-styles',
#   'thankthemajor',
#   'Seventeen34',
#   'Apprentice57',
#   'camelCaseLaws',
#   'Another_Damn_Idiot',
#   'WictImov',
#   'hmtee3',
#   'Marcus_Kovac',
#   'XiphosAletheria',
#   'Ottomatik80',
#   'NoGoodMc',
#   'Different_Pie9854',
#   'Fargason',
#   'Cowbeller',
#   'sohmeho',
#   '303_Colorado_303',
#   'foople',
#   'EchoRex',
#   'NUMBERS2357',
#   '2weirdy',
#   'Dante451',
#   'mjot_007',
#   'geist7204',
#   'Mattcwu',
#   'drag0nw0lf',
#   'Bleyo',
#   'DiligentFriendship96',
#   'pm_favorite_boobs',
#   'Eisn',
#   'cruelhumor',
#   'dietcheese',
#   'Bmorgan1983',
#   'Fredthefree',
#   'jerfoo',
#   'zaoldyeck',
#   'bro_please',
#   'jbondyoda',
#   'NeutralverseBot',
#   'BirdLawConnoisseur',
#   'relato',
#   'pug_subterfuge',
#   'bradp1234',
#   'fullautohotdog',
#   'Duluthian2',
#   'accountability_bot',
#   'codeByNumber',
#   'Huskerdudoo',
#   'NotJustAmy',
#   'hopper_froggo',
#   '__Geg__',
#   'Crankyshaft',
#   'reverendrambo',
#   'DeusExMockinYa',
#   'yeswenarcan',
#   'infininme',
#   'klieber',
#   'WalterFStarbuck',
#   'm_rt_',
#   'Vaadwaur',
#   'SuddenlySusanStrong',
#   'fucklawyers',
#   'cresdon',
#   'bilabrin',
#   'EpsilonRose',
#   'Surfn2live',
#   'overzealous_dentist',
#   'Timberwolf501st',
#   'niftucal92',
#   'Malaveylo',
#   'Corellian_Browncoat',
#   'Hotal',
#   'GreyJedi56',
#   'skratchx',
#   'Lasereye',
#   'mrrektstrong',
#   'gaffman23',
#   'microActive',
#   'TekkDub',
#   'Ineludible_Ruin',
#   'MajorTim1100',
#   'Dassund76',
#   'johnly81',
#   'scaradin',
#   'sawdeanz',
#   'Riecth',
#   'Eyegore138',
#   'jim25y',
#   'joaoasousa',
#   'Pupmup',
#   'Neptunemonkey',
#   'fjonk',
#   'justins_dad',
#   'Hats_back',
#   'Zoomwafflez',
#   'PrettyDecentSort',
#   'WillyPete',
#   'usmclvsop',
#   'LamentForIcarus',
#   'speed_phreak',
#   'akuthia',
#   'shoneysbreakfast',
#   'banjosuicide',
#   'WarmOutOfTheDryer',
#   'xAtlas5',
#   'formermime',
#   'Fdsasd234',
#   'apatheticviews',
#   'moobiemovie',
#   'brotherYamacraw',
#   'mclumber1',
#   'The_Real_Slack',
#   'jtunzi',
#   'wineandcheese',
#   'nemthenga',
#   'cjicantlie',
#   'brightlancer',
#   'RecursiveParadox',
#   'VioletRing77',
#   'digging_for_fire',
#   'zMerovingian',
#   'NotSoVacuous',
#   'MeowTheMixer',
#   'kingjoe64',
#   'Aure-lius',
#   'Pishki-doodle',
#   'lmaginaryMenagerie',
#   'Broad_Contribution4',
#   'xxshteviexx',
#   'uihrqghbrwfgquz',
#   'TheKleen',
#   'District98',
#   'Reesesaholic',
#   'yo-chill',
#   'implicitpharmakoi',
#   'Dokibatt',
#   'Danskheart',
#   'adacmswtf1',
#   'spicy__southpaw',
#   'gkcontra',
#   'Krabilon',
#   'mnouquet',
#   'Nessie',
#   'NotTheThinker',
#   'thehuntofdear',
#   'nyckidd',
#   'JelqingCloaca',
#   'Cucumbers_R_Us',
#   'Fleckeri',
#   'FlyingFreakinRodent',
#   'rynebrandon',
#   'AncientInsults',
#   'AmoebaMan',
#   '3yearstraveling',
#   'Delicious-Ad-7490',
#   'cjt09',
#   'iBleeedorange',
#   'Insofar1846',
#   'Fiji-Refugee',
#   'KeroseneNupe',
#   'PuttPutt7',
#   'serioususeorname',
#   'majorchamp',
#   'Korwinga',
#   'Ok_Ticket_6237',
#   'DUPCangeLCD',
#   'CarRamRob',
#   'Kolada',
#   'fTwoEight',
#   'BrokenGlassFactory',
#   'ckach',
#   '4kray',
#   'Tarantio',
#   'sound_of_apocalypto',
#   'spooky_butts',
#   '00zau',
#   'Party-Garbage4424',
#   'indyaj',
#   'crymson7',
#   'jedibassist',
#   'FSDLAXATL',
#   'DalekForeal',
#   'noimtotallynotatroll',
#   'InternetUser007',
#   'OmahaVike',
#   'lamiscaea',
#   'BenFoldsFourLoko',
#   'TransplantedTree212',
#   'Nicholas-DM',
#   'Kershiser22',
#   'udfgt',
#   'Teeklin',
#   'SeeShark',
#   'Squirrels_Gone_Wild',
#   'Wolf97',
#   'galacticboy2009',
#   'jlevy1126',
#   'CrowVsWade',
#   'Battlingdragon',
#   'ieatthings',
#   'phadrus56',
#   'Orwellian1',
#   'Jasontheperson',
#   'Loduwijk',
#   'SteadyBender',
#   'thatthatguy',
#   'CaineTL',
#   'phycoticfishman',
#   'roylennigan',
#   'Marathon2021',
#   'Morbidly-Obese-Emu',
#   'phil_g',
#   'kurt75',
#   '10wuebc',
#   'glassOfWaterForXmas',
#   'nunyabiznatch1',
#   'philosoraptor_',
#   'jabberwockxeno',
#   'kent_eh',
#   'ThroughlyDruxy',
#   'SevenandForty',
#   'schreibeheimer',
#   'lexi_the_bunny',
#   'sovnade',
#   'omniwombatius',
#   'stamatt45',
#   'SirMrGnome',
#   'TheNaziSpacePope',
#   'Daotar',
#   'brkdncr',
#   'nadamuchu',
#   'Pianoplunkster',
#   'RagingAnemone',
#   'LordBrandon',
#   'katydidy',
#   'CoachSteveOtt',
#   'nowthatsrich',
#   'Khanthulhu',
#   'Tandria',
#   'hglman',
#   'klstopp',
#   'UserAbuser101',
#   'amd2800barton',
#   'maest',
#   'nezmito',
#   'IXISIXI',
#   'shatteredarm1',
#   'Grimesy2',
#   'tanglisha',
#   'SomeGuy565',
#   'CoolioDaggett',
#   'theotherkevin23',
#   'AZPolicyGuy',
#   'snowe2010',
#   'Akitten',
#   'Mattsh102',
#   'cutelyaware',
#   'DB6135',
#   'hortonian_ovf',
#   'jyper',
#   'lurgburg',
#   'DiscordRUs',
#   'Just_Treading_Water',
#   'isingtomytables',
#   'melmoth_to_a_flame',
#   'geak78',
#   'VCRdrift',
#   'AutoModerator',
#   'loftwyr',
#   'chair_78',
#   'linuxhiker',
#   'Lysergic-D',
#   'IvanMSRB',
#   'LibertyLizard',
#   'BrudaBru',
#   'SirNedKingOfGila',
#   'zethien',
#   'starrdev5',
#   'Buck_Thorn',
#   'TrueTorontoFan',
#   'Horny20yrold',
#   'JackJack65',
#   'magicsonar',
#   'chip_0',
#   'JamesArthemeusFin',
#   'RotANobot',
#   'Warsaw14',
#   'doingmeafacsinante',
#   'Darkeyescry22',
#   'Elend15',
#   'as012qwe',
#   'Royal_Code_6440',
#   'alex_reds',
#   'Mythril_Zombie',
#   'taubnetzdornig',
#   '444treasurer444',
#   'Borne2Run',
#   'UnrepentantDrunkard',
#   'ThreatLevelNoonday',
#   'winterfresh0',
#   'velocibadgery',
#   'alwaysmispells1word',
#   'mywan',
#   'BurntPunk',
#   'Dogzirra',
#   'Boring_Philosophy160',
#   'Poormidlifechoices',
#   'bilyl',
#   'uncle_stinky',
#   'skywaters88',
#   'DraconianDebate',
#   'tmmzc85',
#   'Metafx',
#   'BrainofBorg',
#   'dabreadsticks',
#   'gooder_name',
#   'Sciencetist',
#   'beachandbyte',
#   'atomfullerene',
#   'Crayboff',
#   'friend_jp',
#   'patricksaurus',
#   'ultranothing',
#   'N0Catharsis',
#   'heavy_on_the_lettuce',
#   'tankydhg',
#   'mackinator3',
#   '-LetterToTheRedditor',
#   'Kaiser1a2b',
#   'DJConwayTwitty',
#   'icenjam',
#   'JustinCayce',
#   'calantus',
#   'inahst',
#   'MoreTuple',
#   'yebyen',
#   'cmlondon13',
#   'detourxp',
#   'hubau',
#   'pearlday',
#   'dyno0919',
#   'kwantsu-dudes',
#   'atlas1171',
#   'mrloube',
#   'scubascratch',
#   'afrofrycook',
#   'AM_Kylearan',
#   'DancesWithDownvotes',
#   'Montaire',
#   'passthefist',
#   'Tambien',
#   'farcetragedy',
#   'redditisdumb2018',
#   'Jen0BIous',
#   'frowawayacct1111',
#   'beardedheathen',
#   'captain-burrito',
#   'Seansicle',
#   'draekia',
#   'Groovychick1978',
#   'HoodooSquad',
#   'Pseudoboss11',
#   'creativeNameHere555',
#   'lol-da-mar-s-cool',
#   'zomenox',
#   'ocnwave',
#   'Whitticker',
#   'The_Weakpot',
#   'probablyagiven',
#   'justahominid',
#   'FlexicanAmerican',
#   'toterra',
#   'olop4444',
#   'oldvlognewtricks',
#   'tx4468',
#   'jakwnd',
#   'skatastic57',
#   'cowtow',
#   'MGSsancho',
#   'Sidneymcdanger',
#   'kamunoz',
#   'Necoras',
#   'Llamalord73',
#   'PM_ME_NUDE_KITTENS',
#   'drunkosaurous',
#   'josejose50',
#   'jonboy345',
#   'lordcheeto',
#   'Swords_and_Such',
#   'Long-Acanthaceae5369',
#   'ConflagWex',
#   'pburydoughgirl',
#   'schmidit',
#   'nickleback_official',
#   'bassistciaran',
#   'Topcity36',
#   'Theost520',
#   'Cendeu',
#   'MemeLovingLoser',
#   'PostingSomeToast',
#   'iKnitSweatas',
#   'sh1tbox1',
#   'nathhad',
#   'exegesisClique',
#   'badmodofinga',
#   'Gbrew555',
#   'boleslaw_chrobry',
#   'ScannerBrightly',
#   'sailorbrendan',
#   'C12H23',
#   'Nya7',
#   'grandphuba',
#   'MrFrogy',
#   'HardCounter',
#   '_clydebruckman',
#   'Wolv90',
#   'turbo_triforce',
#   'meowgrrr',
#   'kalasea2001',
#   'Rifleshoot',
#   'miami2881',
#   'PB4UGAME',
#   'Allydarvel',
#   'zePiNdA',
#   'Dr_Dickem_MD',
#   'mrcrassic',
#   'chaosink',
#   'Valendr0s',
#   'Toptomcat',
#   'lwal3544',
#   'ExperimentalFailures',
#   'Xorondras',
#   'VelvitHippo',
#   'rasmustrew',
#   'qinosen',
#   'sophacles',
#   'eterevsky',
#   'avocadro',
#   'souporwitty',
#   'TheDal',
#   'monumentdefleurs',
#   'Revan343',
#   'ShortWoman',
#   'braiam',
#   'Frencil',
#   'GoodByeRubyTuesday87',
#   'TheAlias6',
#   'JeffreyElonSkilling',
#   'PM_Me_Unpierced_Ears',
#   'VoiceOfLunacy',
#   'Bartolos_Cologne',
#   'Disasstah',
#   'Fkn_Impervious',
#   'someguyfromtheuk',
#   'WACKY_ALL_CAPS_NAME',
#   'pipocaQuemada',
#   'Arctem',
#   'towishimp',
#   'Pardonme23',
#   'rickvanwinkle',
#   'Kanteloop',
#   'HurricaneCarti',
#   'Descolata',
#   'Die-Nacht',
#   'Joe_Jeep',
#   'ggill1313',
#   'element114',
#   'Emp_Vanilla',
#   'On3_BadAssassin',
#   'shoemilk',
#   'sangueblu03',
#   'amorphousguy',
#   'wienercat',
#   'ViagraSandwich',
#   'jdruth',
#   'sarcasmic77',
#   'HerbertWest',
#   'nd20',
#   'SPQR191',
#   'leperaffinity56',
#   'RAGC_91',
#   'Joele1',
#   'StipularSauce77',
#   'slaya222',
#   'gsupanther',
#   'qchisq',
#   'Dangerous-Hedgehog12',
#   'aeternus-eternis',
#   'ggrizzlyy',
#   'MDCCCLV',
#   'earthwormjim91',
#   'bnav1969',
#   'rbesfe',
#   'nasisakk',
#   'Heyyy_ItsCaitlyn',
#   'joenot443',
#   'thebenshapirobot',
#   'drrew76',
#   'Xipher',
#   'ReluctantRedditor275',
#   'ThrowingChicken',
#   'evil_burrito',
#   'checkyourfallacy',
#   'Sir0bin',
#   'Jaanold',
#   'Corm',
#   'kJer',
#   'jamesTcrusher',
#   'PeckyKoolo',
#   'ShawnaR89',
#   'your______here',
#   'mattemer',
#   'grygrx',
#   'Joben86',
#   'ConverseCLownShoes',
#   'nyanlol',
#   'RahRah617',
#   'curiouskiwicat',
#   'digital_end',
#   'chattytrout',
#   'ThrowdoBaggins',
#   'cafffaro',
#   'Gars0n',
#   'TrickyPlastic',
#   'davehouforyang',
#   'serpentine1337',
#   'perrosrojo',
#   'kkkkat',
#   'ItsFinesseBro',
#   'Forest-Ferda-Trees',
#   'Zarxrax',
#   'Trinition',
#   'GreatBallsOfFIRE',
#   'Autoxidation',
#   'PocketSandInc',
#   'The_Mayfair_Man',
#   'LibertyTerp',
#   'vmlinux',
#   'ESCAPE_PLANET_X',
#   'Player276',
#   'DrunkenAsparagus',
#   'greennick',
#   'binaryice',
#   'TipStrange4693',
#   'Pirat6662001',
#   'Hartastic',
#   'Andthentherewasbacon',
#   'Thackman46',
#   'zytz',
#   'tupacsnoducket',
#   'photoncatcher',
#   'Betasheets',
#   'Nausved',
#   'vankorgan',
#   'albitzian',
#   'surreptitioussloth',
#   'Rivea_',
#   'Bignicky9',
#   'gstormcrow80',
#   'Antsy27',
#   'WhiteyDude',
#   'SexualizedCucumber',
#   'tiberseptim37',
#   'PeterNguyen2',
#   'kingmayo',
#   'OminousOnymous',
#   'Sharadnar',
#   'The_Crass-Beagle_Act',
#   'wingspantt',
#   'Stop_Sign',
#   'stickmanDave',
#   'C47man',
#   'Tuungsten',
#   'Gusfoo',
#   'Ayle87',
#   'guy_guyerson',
#   'BannanaCommie',
#   'billFoldDog',
#   'fllr',
#   'boobookitty_2000',
#   'lordcirth',
#   'Dozekar',
#   'Jaraqthekhajit',
#   'Professional_Map6274',
#   'binarycow',
#   'katchoo1',
#   'kswimmer811',
#   'ho_li_cao',
#   'imperianalysis',
#   'TheBigOily_Sea_Snake',
#   'Then_Campaign7264',
#   'IT_Chef',
#   'Wiffernubbin',
#   'thurst0n',
#   '2tonsofirony',
#   'posam',
#   'Renson',
#   ...]]

# %%
count = 0
for this_list in network_list:
    users_df = pd.DataFrame()
    rows = []
    for user_name in tqdm(this_list[:500]):
        user_dict = {}
        user_dict['username'] = user_name
        user = reddit.redditor(user_name)
        try:
            if get_user_status(user) == 'active' and str(user_name) not in 'nan': # checks that user isn't suspended/deleted
                if not user.is_mod: #ignore mods

                    comment_array = []
                    timestamps = []
                    reply_timestamps = []
                    comment_toxicities = []

                    try:
                        for this_comment in user.comments.new(limit=15):

                            parent_comment_id = this_comment.parent_id
                            if parent_comment_id.startswith('t3'):
                                parent_comment_id = parent_comment_id[3:]
                                parent = reddit.submission(parent_comment_id)
                            else:
                                parent = reddit.comment(parent_comment_id)

                            parent_timestamp = datetime.fromtimestamp(parent.created_utc)
                            comment_timestamp = datetime.fromtimestamp(this_comment.created_utc)

                            comment_array.append(this_comment.body)
                            comment_toxicities.append(sentiment_toxicity(this_comment.body, **tokenizer_kwargs)[0]['score'])
                            
                            timestamps.append(comment_timestamp)
                            reply_timestamps.append((parent_timestamp, comment_timestamp))

                    except Exception as e:
                        print(e)
                        continue

                    for i in range(len(comment_array)):
#                         comment_array[i] = normalize(nlp((comment_array[i]))) # normalizes comment but leaves as string
                        comment_array[i] = nlp(normalize(nlp((comment_array[i])))) # this normalizes comment and wraps in nlp

                    comment_similarities = []
                    time_intervals = []
                    response_intervals = []

                    for sent_1, sent_2 in combinations(comment_array, 2):

#                         comment_similarities.append(calculate_cosine_sim(sent_1, sent_2)) checks cosine simularity of each comment against the next 
                        comment_similarities.append(sent_1.similarity(sent_2)) # nlp similiarity

                    successive_times = list(pairwise(timestamps))
                    for pair in successive_times: # calculates the intervals between user's comments
                        time_intervals.append(abs(pair[0] - pair[1]))

                    for pair in reply_timestamps:
                        response_intervals.append(abs(pair[1] - pair[0]))# calculates how quickly a comment replied to its parent

                    try:
                        time_data = pd.Series(time_intervals)
                        avg_time_diff = (time_data.sum()/len(time_data)).round('1s')
                    except Exception as e:
                        print(e)
                        continue

                    try:
                        response_data = pd.Series(response_intervals)
                        avg_reply_speed = (response_data.sum()/len(response_data)).round('1s')
                    except Exception as e:
                        print(e)
                        continue

                    try:
                        avg_comment_similarity = sum(comment_similarities)/len(comment_similarities)
                        avg_toxicity = sum(comment_toxicities)/len(comment_toxicities)
                    except ZeroDivisionError:
                        continue
                    except Exception as e:
                        print(e)
                        continue
                    try:
                        user_dict['avg_comment_similarity'] = avg_comment_similarity # formating dict
                        user_dict['avg_toxicity'] = avg_toxicity
                        user_dict['avg_reply_speed'] = avg_reply_speed
                        user_dict['avg_comment_time_interval'] = avg_time_diff
                        user_dict['comment_intervals'] = time_intervals
                        

                        rows.append(user_dict) 
                    except Exeception as e:
                        print(e)
                        continue

        except Exception as e:
            print(e)
            continue

    users_df = pd.DataFrame.from_dict(rows, orient='columns')
    print(users_df)
    
    if count == 0:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/conservative_strong.csv')
        count += 1
    elif count == 1:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/conservative_weak.csv')
        count += 1
    elif count == 2:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/conspiracy_strong.csv')
        count += 1
    elif count == 3:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/conspiracy_weak.csv')
        count += 1
    elif count == 4:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/worldnews_strong.csv')
        count += 1
    elif count == 5:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/worldnews_weak.csv')
        count += 1
    elif count == 6:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/neutralpolitics_strong.csv')
        count += 1
    else:
        print(count)
        users_df.to_csv(f'{path}/{user_dir}/neutralpolitics_weak.csv')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 57/57 [24:41<00:00, 26.00s/it]
#                 username  avg_comment_similarity  avg_toxicity  \
# 0         Lord-Sprinkles                0.543231      0.061667
# 1     anonymous_lighting                0.515277      0.152353
# 2            Kitsunezaki                0.359128      0.039366
# 3            bleedingjim                0.493410      0.146145
# 4               Jos_Meid                0.675106      0.110253
# 5    Calm-Hovercraft9858                0.291579      0.086737
# 6            bpatches701                0.601845      0.107644
# 7             No_Key4143                0.535140      0.022430
# 8                BillyQz                0.682721      0.112801
# 9           FiendishPole                0.579946      0.056294
# 10          Jizzlobber42                0.527861      0.088315
# 11           HKatzOnline                0.716387      0.010860
# 12              DLDabber                0.351247      0.153454
# 13            BanzaKongo                0.546565      0.219309
# 14              Lola2050                0.566326      0.063682
# 15           JoeBroski09                0.727409      0.023668
# 16              KeyStep8                0.591580      0.314487
# 17          C4RP3_N0CT3M                0.578682      0.136186
# 18            Torque_Bow                0.628003      0.043251
# 19      Steak_N_Cocunuts                0.450822      0.421071
# 20              Ralath0n                0.699376      0.067132
# 21   IncelWomenRespecter                0.701148      0.096728
# 22           BathWifeBoo                0.591569      0.251064
# 23      TruthfulTrolling                0.485052      0.108983
# 24              12161986                0.638228      0.231619
# 25     AFishNamedFreddie                0.517534      0.164383
# 26            humanglove                0.619028      0.407437
# 27  DeliciousPussyNectar                0.505075      0.333042
# 28            MrColepuck                0.651914      0.056650
# 29           ancilla1998                0.419112      0.068605
# 30             TankerD18                0.792307      0.459190
# 31            Cinnadillo                0.617938      0.010304
# 32          SmoothSecond                0.706277      0.076675
# 33            Icylibrium                0.741208      0.164496
# 34      Spartanlegion117                0.577017      0.103918
# 35              flopisit                0.642319      0.279483
# 36        Shirley-Eugest                0.620078      0.026341
# 37              sleeknub                0.572500      0.067783
# 38             ThirdRook                0.420411      0.093585
# 39            Hydrocoded                0.429090      0.096876
#
#    avg_reply_speed avg_comment_time_interval  \
# 0  0 days 04:53:15           0 days 03:32:11
# 1  0 days 07:27:51           0 days 05:02:37
# 2  1 days 17:14:13           5 days 05:05:34
# 3  4 days 00:41:37           0 days 08:30:13
# 4  0 days 02:34:39           0 days 08:33:43
# 5  0 days 00:09:34           0 days 01:44:31
# 6  1 days 03:24:11           0 days 22:10:29
# 7  0 days 08:03:12           2 days 03:13:36
# 8  0 days 08:47:18           0 days 00:10:20
# 9  0 days 07:52:44           0 days 01:29:40
# 10 0 days 16:56:54           4 days 11:19:52
# 11 0 days 14:42:10           2 days 14:49:06
# 12 0 days 05:04:46           0 days 11:42:24
# 13 0 days 08:08:30           5 days 08:16:44
# 14 1 days 03:58:54           1 days 19:30:11
# 15 0 days 00:41:14           0 days 07:19:33
# 16 0 days 01:06:48           0 days 01:09:00
# 17 0 days 04:44:11           0 days 12:29:23
# 18 0 days 02:49:21           0 days 00:26:31
# 19 0 days 08:45:24           0 days 06:40:58
# 20 0 days 02:59:23           0 days 03:47:37
# 21 0 days 04:45:11           0 days 05:53:25
# 22 0 days 03:01:11           0 days 00:33:14
# 23 0 days 06:55:38           0 days 18:54:42
# 24 0 days 04:28:22           0 days 11:46:50
# 25 0 days 05:07:03           0 days 00:19:15
# 26 0 days 08:28:32           0 days 00:03:26
# 27 0 days 02:31:01           0 days 01:00:46
# 28 0 days 03:38:44          21 days 22:58:35
# 29 0 days 03:45:37           0 days 06:23:01
# 30 0 days 06:31:15           0 days 01:29:35
# 31 0 days 17:12:14           0 days 06:10:20
# 32 0 days 13:18:23           0 days 04:18:12
# 33 0 days 04:46:14           0 days 09:37:47
# 34 0 days 04:13:02           2 days 03:18:16
# 35 0 days 04:25:29           0 days 00:40:24
# 36 0 days 06:08:47           1 days 03:19:57
# 37 0 days 06:10:25           0 days 02:35:13
# 38 0 days 09:33:37           0 days 05:59:14
# 39 0 days 09:14:27           0 days 01:18:21
#
#                                     comment_intervals
# 0   [3:47:36, 12:27:43, 0:05:34, 8:08:08, 0:05:33,...
# 1   [1 day, 0:44:12, 7:00:37, 5:16:50, 17:06:16, 1...
# 2   [0:17:25, 0:01:16, 1 day, 18:45:05, 2 days, 8:...
# 3   [2:09:39, 0:02:00, 0:09:09, 0:13:05, 23:37:37,...
# 4   [3 days, 21:12:01, 0:15:29, 4:21:12, 0:10:32, ...
# 5   [3:20:22, 13:19:04, 0:53:51, 0:02:39, 3:40:27,...
# 6   [0:04:15, 1 day, 13:26:26, 1 day, 7:36:00, 1 d...
# 7   [1 day, 17:52:53, 3:41:20, 0:10:51, 1:07:56, 1...
# 8   [0:06:12, 0:08:47, 0:02:48, 0:28:54, 0:02:42, ...
# 9   [4:48:16, 0:02:38, 12:31:08, 0:35:49, 1:06:58,...
# 10  [31 days, 14:07:08, 0:23:38, 2 days, 10:51:16,...
# 11  [23:32:32, 0:37:09, 0:55:34, 0:22:55, 0:45:06,...
# 12  [0:52:40, 0:05:35, 1:10:12, 15:29:32, 0:19:28,...
# 13  [8 days, 20:08:14, 33 days, 0:33:04, 10 days, ...
# 14  [0:56:11, 0:07:09, 0:48:46, 0:53:09, 21 days, ...
# 15  [5:01:27, 2:17:13, 0:06:16, 0:02:48, 0:55:50, ...
# 16  [0:23:54, 0:01:51, 0:01:41, 0:00:46, 0:04:25, ...
# 17  [1 day, 16:33:46, 23:39:49, 1 day, 15:38:36, 1...
# 18  [0:04:33, 3:16:54, 0:54:39, 0:04:05, 0:14:12, ...
# 19  [13:29:40, 0:20:18, 1 day, 10:49:24, 6:09:56, ...
# 20  [1:50:08, 0:04:08, 2:36:43, 0:12:40, 1:55:52, ...
# 21  [0:14:14, 1:40:40, 0:04:03, 0:03:14, 2:43:46, ...
# 22  [2:20:06, 0:52:42, 0:28:13, 1:29:09, 0:00:42, ...
# 23  [1 day, 7:05:01, 0:02:50, 0:07:08, 0:09:41, 0:...
# 24  [1:30:08, 1 day, 17:08:52, 5:20:28, 0:52:08, 0...
# 25  [1:13:53, 0:02:20, 0:04:25, 1:02:39, 0:45:43, ...
# 26  [0:01:18, 0:01:08, 0:02:15, 0:03:17, 0:01:56, ...
# 27  [0:31:04, 0:00:29, 3:39:36, 0:07:43, 0:14:53, ...
# 28  [41 days, 9:41:32, 76 days, 20:31:54, 2:02:56,...
# 29  [16:47:25, 0:03:26, 1:37:52, 1 day, 12:34:19, ...
# 30  [0:33:03, 0:07:45, 0:14:56, 0:09:42, 1:30:12, ...
# 31  [0:05:06, 9:50:09, 0:11:35, 0:07:59, 0:08:00, ...
# 32  [1 day, 1:32:57, 0:12:27, 0:01:58, 0:03:10, 0:...
# 33  [9:37:59, 1:46:30, 1 day, 1:56:46, 0:51:10, 9:...
# 34  [1 day, 1:39:06, 22 days, 2:44:55, 1 day, 12:0...
# 35  [0:06:10, 0:05:11, 0:18:40, 0:04:04, 3:00:12, ...
# 36  [1 day, 9:03:56, 8:37:29, 1 day, 0:34:24, 3 da...
# 37  [0:03:45, 0:02:05, 0:00:39, 0:04:28, 10:24:59,...
# 38  [10:18:33, 0:05:42, 0:10:46, 6:53:20, 16:33:50...
# 39  [1:22:50, 0:02:30, 0:05:30, 0:01:04, 0:46:20, ...
# 0
#  89%|█████████████████████████████████████████████████████████████████████▌        | 446/500 [3:21:12<16:52, 18.76s/it]
# error with request HTTPSConnectionPool(host='oauth.reddit.com', port=443): Max retries exceeded with url: /comments/xxe5wl/?limit=2048&sort=confidence&raw_json=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000165A6F44310>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [3:49:30<00:00, 27.54s/it]
#                 username  avg_comment_similarity  avg_toxicity  \
# 0         Lord-Sprinkles                0.543231      0.061667
# 1       ninernetneepneep                0.480807      0.255682
# 2     Imdatingstaceysmom                0.520881      0.101658
# 3              dirtyALEK                0.581514      0.003297
# 4       AlpacaWarMachine                0.471238      0.010914
# ..                   ...                     ...           ...
# 363      aproudfatherof3                0.283717      0.179715
# 364          kraotic8321                0.610576      0.112414
# 365           biomech120                0.674826      0.061274
# 366    lordoftheeyes2020                0.498657      0.274536
# 367  i_have_a_pet_turkey                0.635723      0.092755
#
#     avg_reply_speed avg_comment_time_interval  \
# 0   0 days 04:53:15           0 days 03:32:11
# 1   0 days 06:18:10           0 days 03:26:36
# 2   0 days 07:35:35           5 days 05:15:53
# 3   0 days 04:46:54           2 days 13:50:40
# 4   0 days 00:20:12           4 days 05:27:17
# ..              ...                       ...
# 363 0 days 04:27:40           1 days 06:12:59
# 364 0 days 10:59:41           8 days 06:34:34
# 365 0 days 04:25:38           4 days 01:29:39
# 366 1 days 08:37:01           0 days 04:29:28
# 367 0 days 06:04:39           0 days 02:27:43
#
#                                      comment_intervals
# 0    [3:47:36, 12:27:43, 0:05:34, 8:08:08, 0:05:33,...
# 1    [0:33:40, 2:15:29, 1:48:38, 1:02:42, 0:24:55, ...
# 2    [0:06:33, 24 days, 3:31:56, 9 days, 20:16:19, ...
# 3    [2 days, 17:53:44, 0:06:05, 1 day, 12:22:25, 0...
# 4    [21 days, 5:30:16, 1 day, 20:08:40, 6 days, 21...
# ..                                                 ...
# 363  [19:01:15, 0:13:19, 3 days, 5:07:09, 1 day, 9:...
# 364  [14 days, 11:22:16, 0:01:05, 16 days, 8:16:35,...
# 365  [1:00:40, 0:08:16, 7 days, 15:20:47, 3 days, 2...
# 366  [6:28:21, 1 day, 8:46:30, 0:03:41, 0:02:17, 0:...
# 367  [3:38:38, 0:01:37, 5:01:04, 0:24:27, 2:35:40, ...
#
# [368 rows x 6 columns]
# 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 122/122 [43:28<00:00, 21.38s/it]
#                 username  avg_comment_similarity  avg_toxicity  \
# 0          BinyaminDelta                0.583534      0.024003
# 1         BackOnThrottle                0.675105      0.001300
# 2                 arnott                0.542244      0.015380
# 3    Aggressive_Egg_9661                0.459175      0.297070
# 4   Ok-Entrepreneur-4466                0.458836      0.248836
# ..                   ...                     ...           ...
# 75         Shanguerrilla                0.721180      0.111688
# 76             poopscarf                0.470599      0.001523
# 77      itspronouncedDRL                0.594191      0.078408
# 78         ARocketToMars                0.724479      0.048917
# 79           nalydpsycho                0.531541      0.128150
#
#    avg_reply_speed avg_comment_time_interval  \
# 0  0 days 07:36:47           0 days 15:40:23
# 1  0 days 07:30:03           7 days 08:27:33
# 2  0 days 06:52:47           0 days 03:44:51
# 3  0 days 08:31:44           9 days 23:31:12
# 4  0 days 20:02:17           0 days 06:05:53
# ..             ...                       ...
# 75 0 days 06:01:42           0 days 02:48:47
# 76 0 days 15:04:49           0 days 23:58:46
# 77 0 days 21:05:36           1 days 12:02:31
# 78 0 days 01:42:40           0 days 04:48:36
# 79 0 days 05:49:01           0 days 02:40:27
#
#                                     comment_intervals
# 0   [0:03:14, 1 day, 12:20:43, 3 days, 3:47:50, 3 ...
# 1   [9 days, 0:48:19, 26 days, 8:42:04, 26 days, 2...
# 2   [0:28:28, 0:11:56, 2:23:05, 21:27:26, 0:23:37,...
# 3   [19:34:57, 1 day, 13:30:03, 50 days, 13:26:45,...
# 4   [0:01:56, 2 days, 18:01:47, 0:03:26, 0:00:55, ...
# ..                                                ...
# 75  [0:45:19, 0:09:07, 0:45:17, 13:04:33, 0:10:34,...
# 76  [1 day, 0:09:43, 18:13:30, 2 days, 13:07:13, 1...
# 77  [15 days, 1:03:12, 0:21:47, 0:03:36, 2 days, 2...
# 78  [1 day, 1:45:55, 0:17:16, 0:08:53, 0:05:28, 0:...
# 79  [0:01:16, 11:00:00, 0:41:53, 0:07:07, 0:27:50,...
#
# [80 rows x 6 columns]
# 2
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [3:39:55<00:00, 26.39s/it]
#                 username  avg_comment_similarity  avg_toxicity  \
# 0          BinyaminDelta                0.583534      0.024003
# 1       XxSpruce_MoosexX                0.553241      0.094519
# 2    Wrong-Paramedic7489                0.372758      0.228668
# 3      renaissancetrader                0.482290      0.036122
# 4     groupthinkhivemind                0.378224      0.110411
# ..                   ...                     ...           ...
# 366         Snookcatcher                0.528110      0.108619
# 367        AShipChandler                0.710303      0.148853
# 368           EZforme885                0.648270      0.044154
# 369        Shlimeeeeeeee                0.720600      0.050850
# 370        user_name1983                0.682840      0.059107
#
#     avg_reply_speed avg_comment_time_interval  \
# 0   0 days 07:36:47           0 days 15:40:23
# 1   0 days 07:40:44           0 days 09:14:15
# 2   0 days 11:06:22           0 days 12:00:42
# 3   0 days 06:15:16           2 days 19:25:02
# 4   0 days 04:17:39           0 days 07:03:25
# ..              ...                       ...
# 366 0 days 09:13:23           0 days 17:09:11
# 367 0 days 07:01:34           0 days 02:44:34
# 368 0 days 05:33:32           1 days 09:25:52
# 369 0 days 02:57:27           0 days 06:11:48
# 370 1 days 07:26:31           0 days 01:48:21
#
#                                      comment_intervals
# 0    [0:03:14, 1 day, 12:20:43, 3 days, 3:47:50, 3 ...
# 1    [5:23:21, 7:03:15, 0:24:41, 0:11:56, 16:10:41,...
# 2    [4:18:49, 0:23:11, 1:57:45, 16:26:12, 0:02:03,...
# 3    [1 day, 21:55:08, 23 days, 9:36:33, 2 days, 18...
# 4    [1 day, 10:07:09, 4:04:59, 0:09:29, 11:34:56, ...
# ..                                                 ...
# 366  [1 day, 14:24:05, 21:53:07, 1 day, 21:45:00, 1...
# 367  [0:52:18, 4:03:58, 1:08:49, 0:24:09, 0:29:09, ...
# 368  [5 days, 1:22:41, 22:45:28, 1 day, 10:31:55, 1...
# 369  [0:16:37, 1 day, 23:04:54, 0:10:43, 0:00:50, 2...
# 370  [15:37:24, 0:02:39, 3:41:50, 0:22:07, 0:02:01,...
#
# [371 rows x 6 columns]
# 3
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [18:27<00:00, 36.92s/it]
#                 username  avg_comment_similarity  avg_toxicity  \
# 0             bichonista                0.652058      0.066850
# 1                 dunnkw                0.646525      0.131262
# 2             kingmoobot                0.516335      0.183417
# 3           BloopityBlue                0.710963      0.153116
# 4              Alemaya34                0.531396      0.008200
# 5   Realistic-Demand-615                0.449127      0.193052
# 6         pipsdontsqueak                0.566625      0.018835
# 7              honkballs                0.613111      0.093612
# 8          Standgeblasen                0.527708      0.158313
# 9               backupJM                0.734480      0.000715
# 10  ThrowThemUnderTheBus                0.313694      0.219269
# 11           ChairOwn118                0.602454      0.067811
# 12               baquish                0.339246      0.122184
# 13    PreviouslyBannedXD                0.703062      0.048093
# 14               Yisshyo                0.440612      0.009471
# 15   Downtown-Cover-2956                0.380441      0.073257
# 16      iDontKnowBro2020                0.583356      0.029938
# 17      High_Ground_Sand                0.416540      0.126876
# 18    absolute_zenologia                0.397573      0.142245
# 19      GabrielNathaniel                0.370488      0.249940
# 20         ArcticRedwood                0.514934      0.183202
# 21        Llama_Sandwich                0.604856      0.328608
# 22        LieutenantW0rf                0.380919      0.030603
# 23     too-legit-to-quit                0.508423      0.200933
# 24           Micky-OMick                0.450897      0.295588
#
#      avg_reply_speed avg_comment_time_interval  \
# 0    0 days 04:11:58           0 days 23:45:30
# 1    0 days 04:06:04           0 days 05:13:15
# 2    0 days 01:55:56           0 days 09:59:11
# 3    0 days 06:22:02           0 days 02:23:43
# 4    0 days 10:34:54          20 days 02:35:17
# 5    0 days 14:55:21           0 days 17:20:57
# 6    0 days 07:10:44           0 days 03:20:48
# 7    0 days 07:20:37           8 days 22:08:40
# 8    0 days 11:38:07           0 days 23:07:05
# 9    0 days 00:49:53           0 days 00:28:31
# 10   0 days 06:24:14           1 days 06:54:07
# 11  39 days 18:13:02           0 days 13:37:17
# 12   4 days 05:18:08          28 days 19:07:11
# 13 101 days 08:02:11           8 days 04:37:58
# 14   0 days 14:27:40          15 days 03:24:33
# 15   0 days 04:30:59           0 days 03:16:06
# 16  21 days 10:15:49           2 days 16:35:00
# 17   0 days 08:42:46           0 days 04:21:14
# 18   0 days 01:53:18           1 days 14:10:10
# 19   0 days 03:30:09           0 days 00:34:38
# 20   0 days 03:59:51           0 days 05:03:45
# 21   0 days 06:19:41           0 days 05:40:22
# 22   4 days 14:24:14          89 days 10:13:01
# 23   0 days 04:40:16           0 days 20:13:55
# 24   1 days 14:37:35           2 days 15:03:35
#
#                                     comment_intervals
# 0   [2 days, 4:46:28, 1 day, 13:57:41, 18:25:22, 1...
# 1   [0:09:38, 0:01:03, 1:07:02, 11:11:23, 22:14:53...
# 2   [22:14:11, 21:40:52, 1 day, 4:51:02, 0:28:39, ...
# 3   [1:18:56, 0:18:39, 6:49:41, 2:04:02, 0:44:37, ...
# 4   [0:00:49, 14:06:52, 0:00:16, 22:22:24, 0:00:21...
# 5   [23:47:07, 0:02:22, 2 days, 7:06:12, 17:16:33,...
# 6   [0:01:09, 0:10:55, 0:10:57, 12:59:37, 8:13:08,...
# 7   [23:38:37, 7 days, 3:44:53, 1:33:49, 0:00:30, ...
# 8   [13:55:03, 15:13:34, 3 days, 9:14:48, 3 days, ...
# 9   [3:03:38, 0:03:56, 1:38:45, 0:02:10, 0:07:10, ...
# 10  [0:26:16, 0:01:00, 0:03:25, 3 days, 20:31:23, ...
# 11  [1 day, 3:58:50, 2:55:24, 0:23:05, 0:10:16, 16...
# 12  [141 days, 6:35:36, 0:00:12, 0:00:13, 0:00:23,...
# 13  [28 days, 15:24:26, 4 days, 2:54:40, 0:01:25, ...
# 14  [26 days, 7:11:27, 43 days, 2:08:27, 2:28:37, ...
# 15  [6:34:39, 0:00:53, 13:22:14, 0:05:30, 2:14:59,...
# 16  [5 days, 14:27:15, 1 day, 3:35:08, 2 days, 5:3...
# 17  [13:38:18, 7:16:35, 0:53:41, 0:22:03, 7:15:59,...
# 18  [1 day, 23:20:02, 0:05:13, 11 days, 0:57:23, 6...
# 19  [0:12:40, 2:11:23, 0:00:41, 0:51:03, 0:05:37, ...
# 20  [2:13:34, 0:57:15, 0:03:11, 1:30:55, 2:44:49, ...
# 21  [6:46:50, 1 day, 17:01:15, 0:10:33, 2:49:30, 0...
# 22  [1:08:36, 0:19:44, 22:12:44, 867 days, 19:15:2...
# 23  [12:07:59, 10:49:27, 11:12:37, 14:18:21, 3 day...
# 24  [0:03:51, 15 days, 23:02:52, 4 days, 2:15:23, ...
# 4
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [4:04:09<00:00, 29.30s/it]
#                 username  avg_comment_similarity  avg_toxicity  \
# 0             bichonista                0.652058      0.066850
# 1    PeopleCanBeThisDumb                0.329302      0.067347
# 2            lordatomosk                0.406619      0.191287
# 3    ResponsibleHall9713                0.459217      0.281489
# 4           TubularStars                0.230988      0.262676
# ..                   ...                     ...           ...
# 376       yeahiliketoast                0.552359      0.016535
# 377               MSR209                0.471159      0.112537
# 378              Go_getr                0.298545      0.069205
# 379               Xipimp                0.612092      0.301041
# 380          SpaceGazebo                0.614977      0.111339
#
#     avg_reply_speed avg_comment_time_interval  \
# 0   0 days 04:11:58           0 days 23:45:30
# 1   6 days 02:28:11           1 days 21:58:26
# 2   0 days 05:28:42           0 days 11:38:34
# 3   0 days 02:16:01           0 days 21:22:53
# 4   0 days 01:08:41           0 days 05:18:12
# ..              ...                       ...
# 376 0 days 06:05:13           3 days 11:24:09
# 377 0 days 08:54:19          15 days 08:23:40
# 378 0 days 07:30:55           5 days 08:14:47
# 379 0 days 04:29:25           0 days 01:18:38
# 380 0 days 05:19:59           4 days 02:08:34
#
#                                      comment_intervals
# 0    [2 days, 4:46:28, 1 day, 13:57:41, 18:25:22, 1...
# 1    [2:03:56, 4 days, 0:14:42, 16:07:03, 7:05:24, ...
# 2    [4:16:17, 11:55:37, 0:01:03, 1 day, 9:56:54, 0...
# 3    [1 day, 1:17:32, 2 days, 22:48:34, 22:14:14, 0...
# 4    [1 day, 1:05:25, 0:11:03, 0:00:37, 0:00:30, 0:...
# ..                                                 ...
# 376  [20:55:16, 25 days, 20:18:36, 0:33:25, 0:03:19...
# 377  [83 days, 9:14:12, 0:04:08, 10 days, 15:16:06,...
# 378  [68 days, 15:12:55, 5:13:47, 10:36:54, 14:39:3...
# 379  [0:23:57, 0:06:45, 5:56:55, 0:00:54, 0:00:48, ...
# 380  [5 days, 8:41:59, 0:01:35, 0:07:27, 2 days, 12...
#
# [381 rows x 6 columns]
# 5
# 100%|██████████████████████████████████████████████████████████████████████████████| 326/326 [2:05:53<00:00, 23.17s/it]
#                  username  avg_comment_similarity  avg_toxicity  \
# 0    uAHlOCyaPQMLorMgqrwL                0.520445      0.007448
# 1          PsychLegalMind                0.851062      0.004064
# 2           dishonestdick                0.529845      0.125218
# 3           BCSWowbagger2                0.770747      0.033683
# 4               tyboxer87                0.752842      0.067452
# ..                    ...                     ...           ...
# 210         roastedoolong                0.835629      0.359948
# 211           Ottomatik80                0.698707      0.185573
# 212       Savings_Mix6280                0.607552      0.018206
# 213         thehildabeast                0.678181      0.141192
# 214               meltbox                0.746530      0.001429
#
#     avg_reply_speed avg_comment_time_interval  \
# 0   1 days 11:07:47           0 days 14:21:58
# 1   0 days 03:34:59           0 days 10:27:04
# 2   0 days 04:02:38           0 days 01:59:58
# 3   0 days 08:44:48           0 days 07:22:24
# 4   0 days 05:47:56           0 days 04:22:48
# ..              ...                       ...
# 210 0 days 08:49:11           0 days 11:50:19
# 211 0 days 00:58:44           0 days 02:10:28
# 212 0 days 08:07:28           2 days 13:48:43
# 213 3 days 00:39:06           0 days 03:03:00
# 214 9 days 02:47:57           0 days 03:55:37
#
#                                      comment_intervals
# 0    [3 days, 4:14:59, 1:11:41, 1 day, 2:11:41, 0:0...
# 1    [0:27:01, 3:09:11, 4:05:10, 1:18:34, 2:58:18, ...
# 2    [0:03:17, 0:11:19, 0:01:44, 0:04:39, 0:05:46, ...
# 3    [5:13:50, 0:24:46, 0:03:33, 1:42:27, 0:15:50, ...
# 4    [0:31:40, 0:24:43, 0:04:14, 2:44:04, 9:56:08, ...
# ..                                                 ...
# 210  [0:02:01, 0:01:02, 0:35:06, 1 day, 18:32:16, 1...
# 211  [0:32:49, 0:08:27, 4:43:21, 0:16:36, 1:57:05, ...
# 212  [2 days, 1:13:03, 2 days, 0:02:09, 3 days, 22:...
# 213  [0:15:29, 0:02:43, 16:06:35, 3:44:10, 1:29:18,...
# 214  [0:02:16, 0:03:33, 0:03:23, 8:50:26, 1 day, 0:...
#
# [215 rows x 6 columns]
# 6
#  96%|██████████████████████████████████████████████████████████████████████████▋   | 479/500 [3:11:03<03:19,  9.52s/it]C:\Users\mhous\AppData\Local\Temp\ipykernel_5360\3945852135.py:61: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   time_data = pd.Series(time_intervals)
# C:\Users\mhous\AppData\Local\Temp\ipykernel_5360\3945852135.py:62: RuntimeWarning: invalid value encountered in double_scalars
#   avg_time_diff = (time_data.sum()/len(time_data)).round('1s')
#  96%|██████████████████████████████████████████████████████████████████████████▉   | 480/500 [3:11:06<02:30,  7.51s/it]
# 'str' object cannot be interpreted as an integer
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [3:21:16<00:00, 24.15s/it]
#                username  avg_comment_similarity  avg_toxicity avg_reply_speed  \
# 0         extantsextant                0.465533      0.001328 0 days 03:38:29
# 1    TheLincolnMemorial                0.567084      0.005383 0 days 05:34:12
# 2            magnabonzo                0.597560      0.004351 0 days 06:43:50
# 3      Kooky-Wafer-6032                0.616092      0.080925 0 days 07:30:45
# 4               xp19375                0.685226      0.000786 0 days 07:43:09
# ..                  ...                     ...           ...             ...
# 343               fjonk                0.636772      0.030766 0 days 01:30:19
# 344         justins_dad                0.497913      0.011527 0 days 04:21:58
# 345           Hats_back                0.699038      0.190526 0 days 03:42:00
# 346         Zoomwafflez                0.615047      0.148695 0 days 03:34:39
# 347           WillyPete                0.292563      0.003467 0 days 05:31:35
#
#     avg_comment_time_interval  \
# 0             5 days 15:43:17
# 1             8 days 03:48:14
# 2             0 days 13:29:40
# 3            10 days 10:11:48
# 4            28 days 20:18:47
# ..                        ...
# 343           0 days 00:32:10
# 344           0 days 10:11:46
# 345           0 days 08:17:24
# 346           0 days 18:57:16
# 347           0 days 02:06:58
#
#                                      comment_intervals
# 0    [1 day, 10:34:08, 0:37:08, 1 day, 21:32:15, 8 ...
# 1    [26 days, 2:18:13, 16:50:37, 8 days, 8:35:42, ...
# 2    [0:09:56, 22:38:36, 1 day, 18:54:26, 0:50:52, ...
# 3    [1 day, 21:14:09, 19 days, 22:01:13, 8 days, 0...
# 4    [0:11:39, 21:32:18, 0:20:06, 73 days, 22:31:32...
# ..                                                 ...
# 343  [0:31:11, 0:02:11, 1:08:30, 0:40:26, 0:01:23, ...
# 344  [2:06:42, 1:58:24, 0:01:30, 0:08:23, 0:17:01, ...
# 345  [1 day, 6:43:33, 23:41:02, 0:02:36, 16:33:06, ...
# 346  [4 days, 14:44:25, 16:28:28, 9:19:44, 5:18:20,...
# 347  [0:00:17, 0:00:10, 0:07:10, 0:03:35, 17:09:05,...
#
# [348 rows x 6 columns]
# 7
